# %% [markdown]
# # CatAPI RAG Inspection
#
# Учебный notebook для инспекции CatAPI RAG в проекте `cat-breed-assistant`.
#
# Данные уже подготовлены заранее и лежат в репозитории, поэтому notebook **не скачивает CatAPI**, **не использует внешние датасеты** и **не чинит Kaggle-зависимости**.
#
# Пайплайн:
#
# ```text
# catapi_breed_documents.jsonl → catapi_chunks.jsonl → embeddings → ChromaDB → retrieval → RAG prompt → answer
# ```

# %% [markdown]
# ## 1. Цель notebook
#
# CatAPI RAG Inspection Notebook
#
# Цель ноутбука — пошагово проверить RAG-пайплайн для Cat Breed Assistant.
#
# В этой версии мы не скачиваем данные из CatAPI и не используем Hugging Face dataset.
#
# У нас уже есть подготовленные файлы:
#
# - `catapi_breed_documents.jsonl`
# - `catapi_chunks.jsonl`
#
# Проверяем путь:
#
# `processed documents → chunks → retrieval → RAG prompt → answer`
#
# Сначала делаем максимально устойчивую версию без pandas, ChromaDB и sentence-transformers, чтобы не ловить конфликты зависимостей в Kaggle.

# %%
import subprocess
from pathlib import Path

REPO_URL = "https://github.com/MataNerdy/cat-breed-assistant.git"
KAGGLE_WORKING = Path("/kaggle/working")
KAGGLE_PROJECT_DIR = KAGGLE_WORKING / "cat-breed-assistant"

if KAGGLE_WORKING.exists():
    if KAGGLE_PROJECT_DIR.exists():
        print(f"Repository already exists: {KAGGLE_PROJECT_DIR}")
    else:
        print(f"Cloning {REPO_URL} into {KAGGLE_PROJECT_DIR}...")
        subprocess.run(
            ["git", "clone", REPO_URL, str(KAGGLE_PROJECT_DIR)],
            check=True,
        )
        print(f"Cloned repository to {KAGGLE_PROJECT_DIR}")
else:
    print("Not running in Kaggle /kaggle/working environment. Skipping clone cell.")
# Out:
# Cloning https://github.com/MataNerdy/cat-breed-assistant.git into /kaggle/working/cat-breed-assistant...
# Cloning into '/kaggle/working/cat-breed-assistant'...
# Cloned repository to /kaggle/working/cat-breed-assistant

# %%
from pathlib import Path
import json
import os
import re
import textwrap
from collections import Counter
from typing import Any, Dict, List, Optional

# %%
def find_file(filename: str, search_roots=None) -> Optional[Path]:
    """
    Ищет файл в типичных местах:
    - текущая папка
    - data/processed/
    - /kaggle/input/
    - /mnt/data/
    """
    if search_roots is None:
        search_roots = [
            Path.cwd(),
            Path.cwd() / "data" / "processed",
            Path("/kaggle/input"),
            Path("/mnt/data"),
        ]

    for root in search_roots:
        if not root.exists():
            continue

        direct = root / filename
        if direct.exists():
            return direct

        # recursive search, useful for Kaggle datasets
        try:
            matches = list(root.rglob(filename))
            if matches:
                return matches[0]
        except Exception:
            pass

    return None


DOCS_PATH = find_file("catapi_breed_documents.jsonl")
CHUNKS_PATH = find_file("catapi_chunks.jsonl")

print("Current working directory:", Path.cwd())
print("Documents path:", DOCS_PATH)
print("Chunks path:", CHUNKS_PATH)

if DOCS_PATH is None:
    print("Не найден catapi_breed_documents.jsonl")

if CHUNKS_PATH is None:
    print("Не найден catapi_chunks.jsonl")
# Out:
# Current working directory: /kaggle/working
# Documents path: /kaggle/working/cat-breed-assistant/data/processed/catapi_breed_documents.jsonl
# Chunks path: /kaggle/working/cat-breed-assistant/data/processed/catapi_chunks.jsonl

# %%
def load_jsonl(path: Path) -> List[Dict[str, Any]]:
    rows = []
    with path.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if line:
                rows.append(json.loads(line))
    return rows


def preview_text(text: str, n: int = 300) -> str:
    if text is None:
        return ""
    text = str(text).replace("\n", " ").strip()
    return text[:n] + ("..." if len(text) > n else "")


def show_json(obj: Any, max_chars: int = 4000):
    text = json.dumps(obj, ensure_ascii=False, indent=2)
    if len(text) > max_chars:
        text = text[:max_chars] + "\n..."
    print(text)


def show_rows(rows: List[Dict[str, Any]], limit: int = 10):
    """
    Простой вывод таблицы без pandas.
    """
    for i, row in enumerate(rows[:limit], start=1):
        print("=" * 80)
        print(f"ROW {i}")
        show_json(row, max_chars=2500)

# %%
if DOCS_PATH is None or CHUNKS_PATH is None:
    raise FileNotFoundError("Нужны оба файла: catapi_breed_documents.jsonl и catapi_chunks.jsonl")

documents = load_jsonl(DOCS_PATH)
chunks = load_jsonl(CHUNKS_PATH)

print("Documents:", len(documents))
print("Chunks:", len(chunks))

doc_breeds = sorted({d.get("breed_name") for d in documents})
chunk_breeds = sorted({c.get("breed_name") for c in chunks})

print("Unique breeds in documents:", len(doc_breeds))
print("Unique breeds in chunks:", len(chunk_breeds))

print("\nFirst 10 breeds:")
for name in chunk_breeds[:10]:
    print("-", name)
# Out:
# Documents: 67
# Chunks: 67
# Unique breeds in documents: 67
# Unique breeds in chunks: 67
#
# First 10 breeds:
# - Abyssinian
# - Aegean
# - American Bobtail
# - American Curl
# - American Shorthair
# - American Wirehair
# - Arabian Mau
# - Australian Mist
# - Balinese
# - Bambino

# %%
print("Document keys:")
print(documents[1].keys())

print("\nDocument example:")
show_json(documents[1], max_chars=3000)
# Out:
# Document keys:
# dict_keys(['doc_id', 'breed_id', 'breed_name', 'source', 'text', 'metadata'])
#
# Document example:
# {
#   "doc_id": "catapi_aege",
#   "breed_id": "aege",
#   "breed_name": "Aegean",
#   "source": "thecatapi",
#   "text": "Breed name: Aegean\nDescription: Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can be excellent cats for families with children.\nTemperament: Affectionate, Social, Intelligent, Playful, Active\nOrigin: Greece\nLife span: 9 - 12 years\nWeight: 3 - 5 kg (7 - 10 lb)\nGrooming level: 3\nEnergy level: 3\nHealth issues score: 1\nChild friendly score: 4\nDog friendly score: 4\nStranger friendly score: 4\nIntelligence score: 3\nHairless: no\nShedding level: 3\nSocial needs score: 4\nVocalisation score: 3\nHypoallergenic: 0\nWikipedia URL: https://en.wikipedia.org/wiki/Aegean_cat",
#   "metadata": {
#     "origin": "Greece",
#     "temperament": "Affectionate, Social, Intelligent, Playful, Active",
#     "life_span": "9 - 12",
#     "wikipedia_url": "https://en.wikipedia.org/wiki/Aegean_cat",
#     "reference_image_id": "ozEvzdVM-",
#     "image_url": null,
#     "hairless": 0,
#     "shedding_level": 3,
#     "social_needs": 4,
#     "vocalisation": 3,
#     "source_url": "https://api.thecatapi.com/v1/breeds"
#   }
# }

# %%
print("Chunk keys:")
print(chunks[0].keys())

print("\nChunk example:")
show_json(chunks[0], max_chars=3000)
# Out:
# Chunk keys:
# dict_keys(['chunk_id', 'doc_id', 'breed_id', 'breed_name', 'source', 'text', 'metadata'])
#
# Chunk example:
# {
#   "chunk_id": "catapi_abys_profile",
#   "doc_id": "catapi_abys",
#   "breed_id": "abys",
#   "breed_name": "Abyssinian",
#   "source": "thecatapi",
#   "text": "Breed name: Abyssinian\nDescription: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals.\nTemperament: Active, Energetic, Independent, Intelligent, Gentle\nOrigin: Egypt\nLife span: 14 - 15 years\nWeight: 3 - 5 kg (7  -  10 lb)\nGrooming level: 1\nEnergy level: 5\nHealth issues score: 2\nChild friendly score: 3\nDog friendly score: 4\nStranger friendly score: 5\nIntelligence score: 5\nHairless: no\nShedding level: 2\nSocial needs score: 5\nVocalisation score: 1\nHypoallergenic: 0\nWikipedia URL: https://en.wikipedia.org/wiki/Abyssinian_(cat)",
#   "metadata": {
#     "breed_id": "abys",
#     "breed_name": "Abyssinian",
#     "source": "thecatapi",
#     "origin": "Egypt",
#     "reference_image_id": "0XYvRd7oD",
#     "wikipedia_url": "https://en.wikipedia.org/wiki/Abyssinian_(cat)",
#     "image_url": null,
#     "hairless": 0,
#     "shedding_level": 2,
#     "social_needs": 5,
#     "vocalisation": 1
#   }
# }

# %%
overview_rows = []

for c in chunks:
    metadata = c.get("metadata", {}) or {}
    overview_rows.append({
        "breed_id": c.get("breed_id"),
        "breed_name": c.get("breed_name"),
        "origin": metadata.get("origin"),
        "wikipedia_url": metadata.get("wikipedia_url"),
        "reference_image_id": metadata.get("reference_image_id"),
        "text_preview": preview_text(c.get("text", ""), 180),
    })

show_rows(overview_rows, limit=5)
# Out:
# ================================================================================
# ROW 1
# {
#   "breed_id": "abys",
#   "breed_name": "Abyssinian",
#   "origin": "Egypt",
#   "wikipedia_url": "https://en.wikipedia.org/wiki/Abyssinian_(cat)",
#   "reference_image_id": "0XYvRd7oD",
#   "text_preview": "Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperamen..."
# }
# ================================================================================
# ROW 2
# {
#   "breed_id": "aege",
#   "breed_name": "Aegean",
#   "origin": "Greece",
#   "wikipedia_url": "https://en.wikipedia.org/wiki/Aegean_cat",
#   "reference_image_id": "ozEvzdVM-",
#   "text_preview": "Breed name: Aegean Description: Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved ..."
# }
# ================================================================================
# ROW 3
# {
#   "breed_id": "abob",
#   "breed_name": "American Bobtail",
#   "origin": "United States",
#   "wikipedia_url": "https://en.wikipedia.org/wiki/American_Bobtail",
#   "reference_image_id": "hBXicehMA",
#   "text_preview": "Breed name: American Bobtail Description: American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats..."
# }
# ================================================================================
# ROW 4
# {
#   "breed_id": "acur",
#   "breed_name": "American Curl",
#   "origin": "United States",
#   "wikipedia_url": "https://en.wikipedia.org/wiki/American_Curl",
#   "reference_image_id": "xnsqonbjW",
#   "text_preview": "Breed name: American Curl Description: Distinguished by truly unique ears that curl back in a graceful arc, offering an alert, perky, happily surprised expression, they cause peopl..."
# }
# ================================================================================
# ROW 5
# {
#   "breed_id": "asho",
#   "breed_name": "American Shorthair",
#   "origin": "United States",
#   "wikipedia_url": "https://en.wikipedia.org/wiki/American_Shorthair",
#   "reference_image_id": "JFPROfGtQ",
#   "text_preview": "Breed name: American Shorthair Description: The American Shorthair is known for its longevity, robust health, good looks, sweet personality, and amiability with children, dogs, and..."
# }

# %%
def find_breed_chunk(breed_query: str) -> Optional[Dict[str, Any]]:
    q = breed_query.lower().strip()
    for chunk in chunks:
        name = str(chunk.get("breed_name", "")).lower()
        breed_id = str(chunk.get("breed_id", "")).lower()
        if q == name or q == breed_id or q in name:
            return chunk
    return None


for breed in ["British Shorthair", "Maine Coon", "Siamese", "Persian", "Sphynx"]:
    print("=" * 100)
    print(breed)
    chunk = find_breed_chunk(breed)

    if chunk is None:
        print("Не найдено")
        continue

    metadata = chunk.get("metadata", {}) or {}

    print("breed_id:", chunk.get("breed_id"))
    print("origin:", metadata.get("origin"))
    print("wikipedia_url:", metadata.get("wikipedia_url"))
    print("reference_image_id:", metadata.get("reference_image_id"))
    print()
    print(preview_text(chunk.get("text", ""), 1200))
# Out:
# ====================================================================================================
# British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
#
# Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people. Temperament: Affectionate, Easy Going, Gentle, Loyal, Patient, calm Origin: United Kingdom Life span: 12 - 17 years Weight: 5 - 9 kg (12 - 20 lb) Grooming level: 2 Energy level: 2 Health issues score: 2 Child friendly score: 4 Dog friendly score: 5 Stranger friendly score: 2 Intelligence score: 3 Hairless: no Shedding level: 4 Social needs score: 3 Vocalisation score: 1 Hypoallergenic: 0 Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
# ====================================================================================================
# Maine Coon
# breed_id: mcoo
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Maine_Coon
# reference_image_id: OOD3VXAQn
#
# Breed name: Maine Coon Description: They are known for their size and luxurious long coat Maine Coons are considered a gentle giant. The good-natured and affable Maine Coon adapts well to many lifestyles and personalities. She likes being with people and has the habit of following them around, but isn’t needy. Most Maine Coons love water and they can be quite good swimmers. Temperament: Adaptable, Intelligent, Loving, Gentle, Independent Origin: United States Life span: 12 - 15 years Weight: 5 - 8 kg (12 - 18 lb) Grooming level: 3 Energy level: 3 Health issues score: 3 Child friendly score: 4 Dog friendly score: 5 Stranger friendly score: 5 Intelligence score: 5 Hairless: no Shedding level: 3 Social needs score: 3 Vocalisation score: 1 Hypoallergenic: 0 Wikipedia URL: https://en.wikipedia.org/wiki/Maine_Coon
# ====================================================================================================
# Siamese
# breed_id: siam
# origin: Thailand
# wikipedia_url: https://en.wikipedia.org/wiki/Siamese_(cat)
# reference_image_id: ai6Jps4sx
#
# Breed name: Siamese Description: While Siamese cats are extremely fond of their people, they will follow you around and supervise your every move, being talkative and opinionated. They are a demanding and social cat, that do not like being left alone for long periods. Temperament: Active, Agile, Clever, Sociable, Loving, Energetic Origin: Thailand Life span: 12 - 15 years Weight: 4 - 7 kg (8 - 15 lb) Grooming level: 1 Energy level: 5 Health issues score: 1 Child friendly score: 4 Dog friendly score: 5 Stranger friendly score: 5 Intelligence score: 5 Hairless: no Shedding level: 2 Social needs score: 5 Vocalisation score: 5 Hypoallergenic: 1 Wikipedia URL: https://en.wikipedia.org/wiki/Siamese_(cat)
# ====================================================================================================
# Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
#
# Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level: 1 Health issues score: 3 Child friendly score: 2 Dog friendly score: 2 Stranger friendly score: 2 Intelligence score: 3 Hairless: no Shedding level: 4 Social needs score: 4 Vocalisation score: 1 Hypoallergenic: 0 Wikipedia URL: https://en.wikipedia.org/wiki/Persian_(cat)
# ====================================================================================================
# Sphynx
# breed_id: sphy
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Sphynx_(cat)
# reference_image_id: BDb8ZXb1v
#
# Breed name: Sphynx Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression. Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle Origin: Canada Life span: 12 - 14 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 2 Energy level: 3 Health issues score: 4 Child friendly score: 4 Dog friendly score: 5 Stranger friendly score: 5 Intelligence score: 5 Hairless: yes Shedding level: 1 Social needs score: 5 Vocalisation score: 5 Hypoallergenic: 1 Wikipedia URL: https://en.wikipedia.org/wiki/Sphynx_(cat)

# %% [markdown]
# ## Первый retrieval без embeddings
#
# Пока не используем ChromaDB и sentence-transformers.
#
# Сначала сделаем простой retrieval:
#
# 1. определяем породу по русским и английским alias;
# 2. если порода найдена — возвращаем chunk этой породы;
# 3. если порода не найдена — используем простой keyword scoring.
#
# Это не финальный semantic RAG, но это устойчивый baseline, который не зависит от Kaggle-окружения.

# %%
BREED_ALIASES = {
    "британ": "British Shorthair",
    "британск": "British Shorthair",
    "british": "British Shorthair",
    "shorthair": "British Shorthair",

    "мейн": "Maine Coon",
    "мейн-кун": "Maine Coon",
    "мейн кун": "Maine Coon",
    "maine": "Maine Coon",
    "coon": "Maine Coon",

    "сфинкс": "Sphynx",
    "sphynx": "Sphynx",
    "hairless": "Sphynx",

    "сиам": "Siamese",
    "siamese": "Siamese",

    "перс": "Persian",
    "персид": "Persian",
    "persian": "Persian",

    "бенгал": "Bengal",
    "bengal": "Bengal",

    "рэгдолл": "Ragdoll",
    "ragdoll": "Ragdoll",

    "абиссин": "Abyssinian",
    "abyssinian": "Abyssinian",
}


def detect_breed_alias(question: str) -> Optional[str]:
    q = question.lower()
    for alias, breed_name in BREED_ALIASES.items():
        if alias in q:
            return breed_name
    return None


test_questions = [
    "Чем британские котики отличаются от обычных?",
    "Расскажи про мейн куна",
    "Как ухаживать за сфинксом?",
    "Сиамская кошка разговорчивая?",
    "Persian cat grooming",
]

for q in test_questions:
    print(q, "→", detect_breed_alias(q))
# Out:
# Чем британские котики отличаются от обычных? → British Shorthair
# Расскажи про мейн куна → Maine Coon
# Как ухаживать за сфинксом? → Sphynx
# Сиамская кошка разговорчивая? → Siamese
# Persian cat grooming → Persian

# %%
STOPWORDS = {
    "the", "a", "an", "and", "or", "of", "to", "in", "with", "cat", "cats",
    "кошка", "кошки", "кот", "коты", "котик", "котики", "про", "как", "чем",
    "что", "это", "у", "за", "и", "в", "на", "от", "для"
}


def tokenize(text: str) -> List[str]:
    text = text.lower()
    text = re.sub(r"[^a-zа-яё0-9\s-]", " ", text)
    tokens = [t.strip() for t in text.split()]
    return [t for t in tokens if len(t) > 2 and t not in STOPWORDS]


def keyword_score(query: str, text: str) -> int:
    q_tokens = set(tokenize(query))
    t_tokens = set(tokenize(text))
    return len(q_tokens & t_tokens)


def keyword_retrieve(question: str, top_k: int = 5) -> List[Dict[str, Any]]:
    scored = []

    for chunk in chunks:
        score = keyword_score(question, chunk.get("text", ""))
        scored.append({
            "score": score,
            "chunk": chunk,
        })

    scored = sorted(scored, key=lambda x: x["score"], reverse=True)
    return scored[:top_k]

# %%
def hybrid_retrieve(question: str, top_k: int = 5) -> Dict[str, Any]:
    detected_breed = detect_breed_alias(question)

    if detected_breed:
        breed_chunk = find_breed_chunk(detected_breed)
        if breed_chunk:
            return {
                "strategy": "alias_exact_breed",
                "detected_breed": detected_breed,
                "results": [
                    {
                        "rank": 1,
                        "score": None,
                        "chunk": breed_chunk,
                    }
                ],
            }

    keyword_results = keyword_retrieve(question, top_k=top_k)

    return {
        "strategy": "keyword_fallback",
        "detected_breed": detected_breed,
        "results": [
            {
                "rank": i + 1,
                "score": item["score"],
                "chunk": item["chunk"],
            }
            for i, item in enumerate(keyword_results)
        ],
    }


def print_retrieval_result(question: str, result: Dict[str, Any]):
    print("=" * 100)
    print("QUESTION:", question)
    print("STRATEGY:", result["strategy"])
    print("DETECTED BREED:", result["detected_breed"])
    print()

    for item in result["results"]:
        chunk = item["chunk"]
        metadata = chunk.get("metadata", {}) or {}

        print("-" * 80)
        print("rank:", item["rank"])
        print("score:", item["score"])
        print("breed:", chunk.get("breed_name"))
        print("breed_id:", chunk.get("breed_id"))
        print("origin:", metadata.get("origin"))
        print("wikipedia_url:", metadata.get("wikipedia_url"))
        print("reference_image_id:", metadata.get("reference_image_id"))
        print("text:", preview_text(chunk.get("text", ""), 500))

# %%
queries = [
    "Чем британские котики отличаются от обычных?",
    "Расскажи про мейн куна",
    "Как ухаживать за сфинксом?",
    "Сиамская кошка разговорчивая и умная?",
    "Persian cat grooming",
    "large gentle cat",
    "round face dense plush coat",
]

for q in queries:
    result = hybrid_retrieve(q, top_k=5)
    print_retrieval_result(q, result)
# Out:
# ====================================================================================================
# QUESTION: Чем британские котики отличаются от обычных?
# STRATEGY: alias_exact_breed
# DETECTED BREED: British Shorthair
#
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
# text: Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people. Temperament: Affectionat...
# ====================================================================================================
# QUESTION: Расскажи про мейн куна
# STRATEGY: alias_exact_breed
# DETECTED BREED: Maine Coon
#
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Maine Coon
# breed_id: mcoo
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Maine_Coon
# reference_image_id: OOD3VXAQn
# text: Breed name: Maine Coon Description: They are known for their size and luxurious long coat Maine Coons are considered a gentle giant. The good-natured and affable Maine Coon adapts well to many lifestyles and personalities. She likes being with people and has the habit of following them around, but isn’t needy. Most Maine Coons love water and they can be quite good swimmers. Temperament: Adaptable, Intelligent, Loving, Gentle, Independent Origin: United States Life span: 12 - 15 years Weight: 5 -...
# ====================================================================================================
# QUESTION: Как ухаживать за сфинксом?
# STRATEGY: alias_exact_breed
# DETECTED BREED: Sphynx
#
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Sphynx
# breed_id: sphy
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Sphynx_(cat)
# reference_image_id: BDb8ZXb1v
# text: Breed name: Sphynx Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression. Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle Origin: Canada Life span: 12 - 14 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 2 Energy level: 3 Health issues score: 4 Child friendly score:...
# ====================================================================================================
# QUESTION: Сиамская кошка разговорчивая и умная?
# STRATEGY: alias_exact_breed
# DETECTED BREED: Siamese
#
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Siamese
# breed_id: siam
# origin: Thailand
# wikipedia_url: https://en.wikipedia.org/wiki/Siamese_(cat)
# reference_image_id: ai6Jps4sx
# text: Breed name: Siamese Description: While Siamese cats are extremely fond of their people, they will follow you around and supervise your every move, being talkative and opinionated. They are a demanding and social cat, that do not like being left alone for long periods. Temperament: Active, Agile, Clever, Sociable, Loving, Energetic Origin: Thailand Life span: 12 - 15 years Weight: 4 - 7 kg (8 - 15 lb) Grooming level: 1 Energy level: 5 Health issues score: 1 Child friendly score: 4 Dog friendly sc...
# ====================================================================================================
# QUESTION: Persian cat grooming
# STRATEGY: alias_exact_breed
# DETECTED BREED: Persian
#
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level: 1 Health issues score: 3 Child friendly score: 2...
# ====================================================================================================
# QUESTION: large gentle cat
# STRATEGY: keyword_fallback
# DETECTED BREED: None
#
# --------------------------------------------------------------------------------
# rank: 1
# score: 1
# breed: Abyssinian
# breed_id: abys
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Abyssinian_(cat)
# reference_image_id: 0XYvRd7oD
# text: Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperament: Active, Energetic, Independent, Intelligent, Gentle Origin: Egypt Life span: 14 - 15 years Weight: 3 - 5 kg (7  -  10 lb) Grooming level: 1 Energy level: 5 Health issues score: 2 Child friendly score: 3 Dog friendly score: 4 Stranger friendly score: 5 Intelligence score: 5 Hairless: no Shedding level: 2 Social needs...
# --------------------------------------------------------------------------------
# rank: 2
# score: 1
# breed: American Wirehair
# breed_id: awir
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/American_Wirehair
# reference_image_id: 8D--jCd21
# text: Breed name: American Wirehair Description: The American Wirehair tends to be a calm and tolerant cat who takes life as it comes. His favorite hobby is bird-watching from a sunny windowsill, and his hunting ability will stand you in good stead if insects enter the house. Temperament: Affectionate, Curious, Gentle, Intelligent, Interactive, Lively, Loyal, Playful, Sensible, Social Origin: United States Life span: 14 - 18 years Weight: 4 - 7 kg (8 - 15 lb) Grooming level: 1 Energy level: 3 Health i...
# --------------------------------------------------------------------------------
# rank: 3
# score: 1
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level: 5 Health issues score: 1 Child friendly score: 4...
# --------------------------------------------------------------------------------
# rank: 4
# score: 1
# breed: Birman
# breed_id: birm
# origin: France
# wikipedia_url: https://en.wikipedia.org/wiki/Birman
# reference_image_id: HOrX5gwLS
# text: Breed name: Birman Description: The Birman is a docile, quiet cat who loves people and will follow them from room to room. Expect the Birman to want to be involved in what you’re doing. He communicates in a soft voice, mainly to remind you that perhaps it’s time for dinner or maybe for a nice cuddle on the sofa. He enjoys being held and will relax in your arms like a furry baby. Temperament: Affectionate, Active, Gentle, Social Origin: France Life span: 14 - 15 years Weight: 3 - 7 kg (6 - 15 lb)...
# --------------------------------------------------------------------------------
# rank: 5
# score: 1
# breed: Bombay
# breed_id: bomb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bombay_(cat)
# reference_image_id: 5iYq9NmT1
# text: Breed name: Bombay Description: The the golden eyes and the shiny black coa of the Bopmbay is absolutely striking. Likely to bond most with one family member, the Bombay will follow you from room to room and will almost always have something to say about what you are doing, loving attention and to be carried around, often on his caregiver's shoulder. Temperament: Affectionate, Dependent, Gentle, Intelligent, Playful Origin: United States Life span: 12 - 16 years Weight: 3 - 5 kg (6 - 11 lb) Groo...
# ====================================================================================================
# QUESTION: round face dense plush coat
# STRATEGY: keyword_fallback
# DETECTED BREED: None
#
# --------------------------------------------------------------------------------
# rank: 1
# score: 1
# breed: Maine Coon
# breed_id: mcoo
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Maine_Coon
# reference_image_id: OOD3VXAQn
# text: Breed name: Maine Coon Description: They are known for their size and luxurious long coat Maine Coons are considered a gentle giant. The good-natured and affable Maine Coon adapts well to many lifestyles and personalities. She likes being with people and has the habit of following them around, but isn’t needy. Most Maine Coons love water and they can be quite good swimmers. Temperament: Adaptable, Intelligent, Loving, Gentle, Independent Origin: United States Life span: 12 - 15 years Weight: 5 -...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0
# breed: Abyssinian
# breed_id: abys
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Abyssinian_(cat)
# reference_image_id: 0XYvRd7oD
# text: Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperament: Active, Energetic, Independent, Intelligent, Gentle Origin: Egypt Life span: 14 - 15 years Weight: 3 - 5 kg (7  -  10 lb) Grooming level: 1 Energy level: 5 Health issues score: 2 Child friendly score: 3 Dog friendly score: 4 Stranger friendly score: 5 Intelligence score: 5 Hairless: no Shedding level: 2 Social needs...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0
# breed: Aegean
# breed_id: aege
# origin: Greece
# wikipedia_url: https://en.wikipedia.org/wiki/Aegean_cat
# reference_image_id: ozEvzdVM-
# text: Breed name: Aegean Description: Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can be excellent cats for families with children. Temperament: Affectionate, Social, Intelligent, Playful, Active Origin: Greece Life span: 9 - 12 years Weight: 3 - 5 kg (...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0
# breed: American Bobtail
# breed_id: abob
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/American_Bobtail
# reference_image_id: hBXicehMA
# text: Breed name: American Bobtail Description: American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion. Temperament: Intelligent, Interactive, Lively, Playful, Sensitive Origin: United States Life span: 11 - 15 years Weight: 3 - 7 kg (7 - 16 lb) Grooming level: 1 Energy level: 3 Health issues score: 1 Child friendly score: 4 Dog friendly score: 5 Stranger friendly s...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0
# breed: American Curl
# breed_id: acur
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/American_Curl
# reference_image_id: xnsqonbjW
# text: Breed name: American Curl Description: Distinguished by truly unique ears that curl back in a graceful arc, offering an alert, perky, happily surprised expression, they cause people to break out into a big smile when viewing their first Curl. Curls are very people-oriented, faithful, affectionate soulmates, adjusting remarkably fast to other pets, children, and new situations. Temperament: Affectionate, Curious, Intelligent, Interactive, Lively, Playful, Social Origin: United States Life span: 1...

# %% [markdown]
# ## Что мы уже проверили
#
# На этом этапе мы ещё не использовали embeddings и ChromaDB.
#
# Но мы уже проверили:
#
# - данные загружаются из JSONL;
# - в данных есть 67 пород;
# - у каждой породы есть текстовый профиль;
# - русские запросы можно связать с породой через alias detection;
# - retrieved context можно явно показать перед генерацией ответа.
#
# Это уже минимальный retrieval layer.
#
# Следующий шаг — собрать RAG prompt.

# %%
SYSTEM_INSTRUCTION = """
Ты — дружелюбный ассистент-консультант по породам кошек.

Отвечай на русском языке.
Используй только факты из retrieved context.
Если информации мало, честно скажи, что данных недостаточно.
Не давай категоричных медицинских советов.
Если вопрос касается здоровья, мягко посоветуй обратиться к ветеринару.
""".strip()


def build_rag_prompt(question: str, retrieved_result: Dict[str, Any]) -> str:
    context_blocks = []

    for item in retrieved_result["results"]:
        chunk = item["chunk"]
        metadata = chunk.get("metadata", {}) or {}

        block = f"""
[Context chunk]
Breed: {chunk.get("breed_name")}
Breed ID: {chunk.get("breed_id")}
Origin: {metadata.get("origin")}
Wikipedia URL: {metadata.get("wikipedia_url")}
Reference image ID: {metadata.get("reference_image_id")}

Text:
{chunk.get("text")}
""".strip()

        context_blocks.append(block)

    context_text = "\n\n---\n\n".join(context_blocks)

    prompt = f"""
SYSTEM INSTRUCTION:
{SYSTEM_INSTRUCTION}

RETRIEVED CONTEXT:
{context_text}

USER QUESTION:
{question}

ANSWER:
""".strip()

    return prompt


question = "Чем британские котики отличаются от обычных?"
retrieved = hybrid_retrieve(question, top_k=5)
prompt = build_rag_prompt(question, retrieved)

print(prompt)
# Out:
# SYSTEM INSTRUCTION:
# Ты — дружелюбный ассистент-консультант по породам кошек.
#
# Отвечай на русском языке.
# Используй только факты из retrieved context.
# Если информации мало, честно скажи, что данных недостаточно.
# Не давай категоричных медицинских советов.
# Если вопрос касается здоровья, мягко посоветуй обратиться к ветеринару.
#
# RETRIEVED CONTEXT:
# [Context chunk]
# Breed: British Shorthair
# Breed ID: bsho
# Origin: United Kingdom
# Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
# Reference image ID: s4wQfYoEk
#
# Text:
# Breed name: British Shorthair
# Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people.
# Temperament: Affectionate, Easy Going, Gentle, Loyal, Patient, calm
# Origin: United Kingdom
# Life span: 12 - 17 years
# Weight: 5 - 9 kg (12 - 20 lb)
# Grooming level: 2
# Energy level: 2
# Health issues score: 2
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 2
# Intelligence score: 3
# Hairless: no
# Shedding level: 4
# Social needs score: 3
# Vocalisation score: 1
# Hypoallergenic: 0
# Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
#
# USER QUESTION:
# Чем британские котики отличаются от обычных?
#
# ANSWER:

# %%
def make_mock_rag_answer(question: str, retrieved_result: Dict[str, Any]) -> str:
    if not retrieved_result["results"]:
        return "Я не нашла подходящий контекст по породам кошек."

    chunk = retrieved_result["results"][0]["chunk"]
    metadata = chunk.get("metadata", {}) or {}

    breed_name = chunk.get("breed_name")
    origin = metadata.get("origin")
    wiki = metadata.get("wikipedia_url")
    ref_image = metadata.get("reference_image_id")

    text = chunk.get("text", "")

    answer = f"""
По найденному контексту речь, скорее всего, про породу **{breed_name}**.

Коротко по данным CatAPI:

{preview_text(text, 900)}

Источник указывает происхождение: **{origin}**.

Это не медицинская консультация: если вопрос касается здоровья, лучше свериться с ветеринаром.

Wikipedia URL: {wiki}
Reference image ID: {ref_image}
""".strip()

    return answer


print(make_mock_rag_answer(question, retrieved))
# Out:
# По найденному контексту речь, скорее всего, про породу **British Shorthair**.
#
# Коротко по данным CatAPI:
#
# Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people. Temperament: Affectionate, Easy Going, Gentle, Loyal, Patient, calm Origin: United Kingdom Life span: 12 - 17 years Weight: 5 - 9 kg (12 - 20 lb) Grooming level: 2 Energy level: 2 Health issues score: 2 Child friendly score: 4 Dog friendly score: 5 Stranger friendly score: 2 Intelligence score: 3 Hairless: no Shedding level: 4 Social needs score: 3 Vocalisation score: 1 Hypoallergenic: 0 Wikipedia URL: https://en.wikiped...
#
# Источник указывает происхождение: **United Kingdom**.
#
# Это не медицинская консультация: если вопрос касается здоровья, лучше свериться с ветеринаром.
#
# Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
# Reference image ID: s4wQfYoEk

# %% [markdown]
# ## Промежуточные выводы
#
# Что получилось:
#
# - мы загрузили готовые CatAPI documents/chunks;
# - проверили, что данные содержат десятки пород;
# - сделали простой retrieval без тяжёлых зависимостей;
# - для русских запросов использовали alias detection;
# - собрали RAG prompt;
# - получили mock answer на основе retrieved context.
#
# Что важно:
#
# - это ещё не vector RAG;
# - зато это уже контролируемый retrieval pipeline;
# - он не зависит от нестабильного Kaggle окружения;
# - теперь понятно, какие факты реально попадают в ответ.
#
# Следующий этап:
#
# 1. добавить embeddings, если окружение позволит;
# 2. попробовать multilingual embedding model;
# 3. подключить этот CatAPI retriever к backend;
# 4. показать retrieved context и картинки в Streamlit.

# %% [markdown]
# ## Диагностика baseline retrieval
#
# Что видно по результатам:
#
# 1. Запросы с явным названием породы работают хорошо через alias detection.
# 2. Keyword fallback работает слабо:
#    - он не понимает смысл;
#    - он не умеет работать с признаками вроде "большая", "спокойная", "длинная шерсть";
#    - он часто выбирает случайную породу с одним совпавшим словом.
#
# Поэтому перед embeddings сделаем более умный baseline:
#
# `query → alias detection → structured CatAPI fields → ranked breeds`
#
# Будем использовать числовые и текстовые признаки из CatAPI:
# - grooming level;
# - energy level;
# - shedding level;
# - vocalisation score;
# - social needs;
# - hairless;
# - weight;
# - temperament;
# - description.

# %%
def extract_field(text: str, field_name: str) -> Optional[str]:
    """
    Достаёт значение поля из текстового профиля вида:
    Field name: value
    """
    pattern = rf"{re.escape(field_name)}:\s*(.*?)(?=\n[A-Z][A-Za-z ]+?:|\Z)"
    match = re.search(pattern, text, flags=re.S)
    if not match:
        return None
    return match.group(1).strip()


def extract_int_field(text: str, field_name: str) -> Optional[int]:
    value = extract_field(text, field_name)
    if value is None:
        return None
    match = re.search(r"\d+", value)
    return int(match.group(0)) if match else None


def parse_weight_kg(text: str) -> Optional[tuple]:
    """
    Достаёт вес в кг из строки вроде:
    Weight: 5 - 9 kg (12 - 20 lb)
    """
    value = extract_field(text, "Weight")
    if not value:
        return None

    match = re.search(r"(\d+)\s*-\s*(\d+)\s*kg", value)
    if not match:
        return None

    return int(match.group(1)), int(match.group(2))


def build_structured_profile(chunk: Dict[str, Any]) -> Dict[str, Any]:
    text = chunk.get("text", "")
    metadata = chunk.get("metadata", {}) or {}

    weight_kg = parse_weight_kg(text)

    return {
        "breed_id": chunk.get("breed_id"),
        "breed_name": chunk.get("breed_name"),
        "origin": metadata.get("origin"),
        "description": extract_field(text, "Description"),
        "temperament": extract_field(text, "Temperament"),
        "life_span": extract_field(text, "Life span"),
        "weight_kg": weight_kg,
        "grooming_level": extract_int_field(text, "Grooming level"),
        "energy_level": extract_int_field(text, "Energy level"),
        "health_issues_score": extract_int_field(text, "Health issues score"),
        "child_friendly_score": extract_int_field(text, "Child friendly score"),
        "dog_friendly_score": extract_int_field(text, "Dog friendly score"),
        "stranger_friendly_score": extract_int_field(text, "Stranger friendly score"),
        "intelligence_score": extract_int_field(text, "Intelligence score"),
        "hairless": extract_field(text, "Hairless"),
        "shedding_level": extract_int_field(text, "Shedding level"),
        "social_needs_score": extract_int_field(text, "Social needs score"),
        "vocalisation_score": extract_int_field(text, "Vocalisation score"),
        "hypoallergenic": extract_int_field(text, "Hypoallergenic"),
        "wikipedia_url": metadata.get("wikipedia_url"),
        "reference_image_id": metadata.get("reference_image_id"),
        "image_url": metadata.get("image_url"),
        "raw_text": text,
    }


profiles = [build_structured_profile(chunk) for chunk in chunks]

print("Structured profiles:", len(profiles))
show_rows(profiles[:3], limit=3)
# Out:
# Structured profiles: 67
# ================================================================================
# ROW 1
# {
#   "breed_id": "abys",
#   "breed_name": "Abyssinian",
#   "origin": "Egypt",
#   "description": "The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals.",
#   "temperament": "Active, Energetic, Independent, Intelligent, Gentle",
#   "life_span": "14 - 15 years",
#   "weight_kg": [
#     3,
#     5
#   ],
#   "grooming_level": 1,
#   "energy_level": 5,
#   "health_issues_score": 2,
#   "child_friendly_score": 3,
#   "dog_friendly_score": 4,
#   "stranger_friendly_score": 5,
#   "intelligence_score": 5,
#   "hairless": "no",
#   "shedding_level": 2,
#   "social_needs_score": 5,
#   "vocalisation_score": 1,
#   "hypoallergenic": 0,
#   "wikipedia_url": "https://en.wikipedia.org/wiki/Abyssinian_(cat)",
#   "reference_image_id": "0XYvRd7oD",
#   "image_url": null,
#   "raw_text": "Breed name: Abyssinian\nDescription: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals.\nTemperament: Active, Energetic, Independent, Intelligent, Gentle\nOrigin: Egypt\nLife span: 14 - 15 years\nWeight: 3 - 5 kg (7  -  10 lb)\nGrooming level: 1\nEnergy level: 5\nHealth issues score: 2\nChild friendly score: 3\nDog friendly score: 4\nStranger friendly score: 5\nIntelligence score: 5\nHairless: no\nShedding level: 2\nSocial needs score: 5\nVocalisation score: 1\nHypoallergenic: 0\nWikipedia URL: https://en.wikipedia.org/wiki/Abyssinian_(cat)"
# }
# ================================================================================
# ROW 2
# {
#   "breed_id": "aege",
#   "breed_name": "Aegean",
#   "origin": "Greece",
#   "description": "Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can be excellent cats for families with children.",
#   "temperament": "Affectionate, Social, Intelligent, Playful, Active",
#   "life_span": "9 - 12 years",
#   "weight_kg": [
#     3,
#     5
#   ],
#   "grooming_level": 3,
#   "energy_level": 3,
#   "health_issues_score": 1,
#   "child_friendly_score": 4,
#   "dog_friendly_score": 4,
#   "stranger_friendly_score": 4,
#   "intelligence_score": 3,
#   "hairless": "no",
#   "shedding_level": 3,
#   "social_needs_score": 4,
#   "vocalisation_score": 3,
#   "hypoallergenic": 0,
#   "wikipedia_url": "https://en.wikipedia.org/wiki/Aegean_cat",
#   "reference_image_id": "ozEvzdVM-",
#   "image_url": null,
#   "raw_text": "Breed name: Aegean\nDescription: Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can be excellent cats for families with children.\nTemperament: Affectionate, Social, Intelligent, Playful, Active\nOrigin: Greece\nLife span: 9 - 12 years\nWeight: 3 - 5 kg (7 - 10 lb)\nGrooming level: 3\nEnergy level: 3\nHealth issues score: 1\nChild friendly score: 4\nDog friendly score: 4\nStranger friendly score: 4\nIntelligence score: 3\nHairless: no\nShedding level: 3\nSocial needs score: 4\nVocalisation score: 3\nHypoallergenic: 0\nWikipedia URL: https://en.wikipedia.org/wiki/Aegean_cat"
# }
# ================================================================================
# ROW 3
# {
#   "breed_id": "abob",
#   "breed_name": "American Bobtail",
#   "origin": "United States",
#   "description": "American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion.",
#   "temperament": "Intelligent, Interactive, Lively, Playful, Sensitive",
#   "life_span": "11 - 15 years",
#   "weight_kg": [
#     3,
#     7
#   ],
#   "grooming_level": 1,
#   "energy_level": 3,
#   "health_issues_score": 1,
#   "child_friendly_score": 4,
#   "dog_friendly_score": 5,
#   "stranger_friendly_score": 3,
#   "intelligence_score": 5,
#   "hairless": "no",
#   "shedding_level": 3,
#   "social_needs_score": 3,
#   "vocalisation_score": 3,
#   "hypoallergenic": 0,
#   "wikipedia_url": "https://en.wikipedia.org/wiki/American_Bobtail",
#   "reference_image_id": "hBXicehMA",
#   "image_url": null,
#   "raw_text": "Breed name: American Bobtail\nDescription: American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion.\nTemperament: Intelligent, Interactive, Lively, Playful, Sensitive\nOrigin: United States\nLife span: 11 - 15 years\nWeight: 3 - 7 kg (7 - 16 lb)\nGrooming level: 1\nEnergy level: 3\nHealth issues score: 1\nChild friendly score: 4\nDog friendly score: 5\nStranger friendly score: 3\nIntelligence score: 5\nHairless: no\nShedding level: 3\nSocial needs score: 3\nVocalisation score: 3\nHypoallergenic: 0\nWikipedia URL: https://en.wikipedia.org/wiki/American_Bobtail"
# }

# %%
for breed in ["British Shorthair", "Maine Coon", "Siamese", "Persian", "Sphynx"]:
    print("=" * 100)
    profile = next((p for p in profiles if p["breed_name"] == breed), None)

    if profile is None:
        print("Not found:", breed)
        continue

    show_json({
        "breed_name": profile["breed_name"],
        "origin": profile["origin"],
        "temperament": profile["temperament"],
        "weight_kg": profile["weight_kg"],
        "grooming_level": profile["grooming_level"],
        "energy_level": profile["energy_level"],
        "shedding_level": profile["shedding_level"],
        "social_needs_score": profile["social_needs_score"],
        "vocalisation_score": profile["vocalisation_score"],
        "hairless": profile["hairless"],
        "description": preview_text(profile["description"], 500),
    })
# Out:
# ====================================================================================================
# {
#   "breed_name": "British Shorthair",
#   "origin": "United Kingdom",
#   "temperament": "Affectionate, Easy Going, Gentle, Loyal, Patient, calm",
#   "weight_kg": [
#     5,
#     9
#   ],
#   "grooming_level": 2,
#   "energy_level": 2,
#   "shedding_level": 4,
#   "social_needs_score": 3,
#   "vocalisation_score": 1,
#   "hairless": "no",
#   "description": "The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people."
# }
# ====================================================================================================
# {
#   "breed_name": "Maine Coon",
#   "origin": "United States",
#   "temperament": "Adaptable, Intelligent, Loving, Gentle, Independent",
#   "weight_kg": [
#     5,
#     8
#   ],
#   "grooming_level": 3,
#   "energy_level": 3,
#   "shedding_level": 3,
#   "social_needs_score": 3,
#   "vocalisation_score": 1,
#   "hairless": "no",
#   "description": "They are known for their size and luxurious long coat Maine Coons are considered a gentle giant. The good-natured and affable Maine Coon adapts well to many lifestyles and personalities. She likes being with people and has the habit of following them around, but isn’t needy. Most Maine Coons love water and they can be quite good swimmers."
# }
# ====================================================================================================
# {
#   "breed_name": "Siamese",
#   "origin": "Thailand",
#   "temperament": "Active, Agile, Clever, Sociable, Loving, Energetic",
#   "weight_kg": [
#     4,
#     7
#   ],
#   "grooming_level": 1,
#   "energy_level": 5,
#   "shedding_level": 2,
#   "social_needs_score": 5,
#   "vocalisation_score": 5,
#   "hairless": "no",
#   "description": "While Siamese cats are extremely fond of their people, they will follow you around and supervise your every move, being talkative and opinionated. They are a demanding and social cat, that do not like being left alone for long periods."
# }
# ====================================================================================================
# {
#   "breed_name": "Persian",
#   "origin": "Iran (Persia)",
#   "temperament": "Affectionate, loyal, Sedate, Quiet",
#   "weight_kg": [
#     4,
#     6
#   ],
#   "grooming_level": 5,
#   "energy_level": 1,
#   "shedding_level": 4,
#   "social_needs_score": 4,
#   "vocalisation_score": 1,
#   "hairless": "no",
#   "description": "Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time."
# }
# ====================================================================================================
# {
#   "breed_name": "Sphynx",
#   "origin": "Canada",
#   "temperament": "Loyal, Inquisitive, Friendly, Quiet, Gentle",
#   "weight_kg": [
#     3,
#     5
#   ],
#   "grooming_level": 2,
#   "energy_level": 3,
#   "shedding_level": 1,
#   "social_needs_score": 5,
#   "vocalisation_score": 5,
#   "hairless": "yes",
#   "description": "The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression."
# }

# %%
def structured_score(question: str, profile: Dict[str, Any]) -> int:
    q = question.lower().replace("ё", "е")
    score = 0

    text_blob = " ".join([
        str(profile.get("breed_name") or ""),
        str(profile.get("description") or ""),
        str(profile.get("temperament") or ""),
        str(profile.get("origin") or ""),
    ]).lower()

    # Базовый keyword overlap
    score += keyword_score(question, text_blob)

    # Размер / вес
    weight = profile.get("weight_kg")
    if weight:
        min_w, max_w = weight
        if any(word in q for word in ["large", "big", "гигант", "больш", "крупн"]):
            if max_w >= 8:
                score += 5
            elif max_w >= 6:
                score += 2

        if any(word in q for word in ["small", "tiny", "маленьк", "небольш"]):
            if max_w <= 5:
                score += 4

    # Характер
    temperament = str(profile.get("temperament") or "").lower()

    if any(word in q for word in ["gentle", "calm", "quiet", "спокойн", "тих", "ласков"]):
        for trait in ["gentle", "calm", "quiet", "easy going", "patient", "affectionate"]:
            if trait in temperament:
                score += 3

    if any(word in q for word in ["active", "energetic", "playful", "активн", "энергич", "игрив"]):
        if (profile.get("energy_level") or 0) >= 4:
            score += 4
        for trait in ["active", "energetic", "playful", "lively"]:
            if trait in temperament:
                score += 2

    if any(word in q for word in ["social", "friendly", "общительн", "дружелюб", "любит людей"]):
        if (profile.get("social_needs_score") or 0) >= 4:
            score += 3
        for trait in ["social", "friendly", "sociable", "loving"]:
            if trait in temperament:
                score += 2

    # Разговорчивость
    if any(word in q for word in ["vocal", "talkative", "разговорч", "болтлив", "мяука"]):
        if (profile.get("vocalisation_score") or 0) >= 4:
            score += 6

    # Интеллект
    if any(word in q for word in ["intelligent", "clever", "умн", "сообразительн"]):
        if (profile.get("intelligence_score") or 0) >= 4:
            score += 4

    # Уход / груминг
    if any(word in q for word in ["grooming", "care", "уход", "вычес", "шерсть"]):
        grooming = profile.get("grooming_level") or 0
        if grooming >= 4:
            score += 5
        elif grooming >= 2:
            score += 2

    # Линька
    if any(word in q for word in ["shedding", "линяет", "линька"]):
        if (profile.get("shedding_level") or 0) >= 4:
            score += 4

    # Голые / сфинксы
    if any(word in q for word in ["hairless", "без шерсти", "лыс", "гол"]):
        if str(profile.get("hairless")).lower() in {"yes", "1", "true"}:
            score += 8

    # Гипоаллергенность
    if any(word in q for word in ["hypoallergenic", "аллерг"]):
        if profile.get("hypoallergenic") == 1:
            score += 5

    return score


def structured_retrieve(question: str, top_k: int = 5) -> List[Dict[str, Any]]:
    scored = []

    for profile in profiles:
        score = structured_score(question, profile)
        scored.append({
            "score": score,
            "profile": profile,
        })

    scored = sorted(scored, key=lambda x: x["score"], reverse=True)
    return scored[:top_k]

# %%
structured_queries = [
    "large gentle cat",
    "большая спокойная кошка",
    "hairless cat care",
    "как ухаживать за сфинксом",
    "vocal intelligent cat",
    "разговорчивая умная кошка",
    "long hair grooming",
    "кошка с высоким уровнем ухода за шерстью",
]

for q in structured_queries:
    print("=" * 100)
    print("QUERY:", q)

    results = structured_retrieve(q, top_k=5)

    for i, item in enumerate(results, start=1):
        p = item["profile"]
        print("-" * 80)
        print("rank:", i)
        print("score:", item["score"])
        print("breed:", p["breed_name"])
        print("temperament:", p["temperament"])
        print("weight_kg:", p["weight_kg"])
        print("grooming:", p["grooming_level"])
        print("energy:", p["energy_level"])
        print("vocalisation:", p["vocalisation_score"])
        print("hairless:", p["hairless"])
        print("description:", preview_text(p["description"], 300))
# Out:
# ====================================================================================================
# QUERY: large gentle cat
# --------------------------------------------------------------------------------
# rank: 1
# score: 21
# breed: British Shorthair
# temperament: Affectionate, Easy Going, Gentle, Loyal, Patient, calm
# weight_kg: (5, 9)
# grooming: 2
# energy: 2
# vocalisation: 1
# hairless: no
# description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will ...
# --------------------------------------------------------------------------------
# rank: 2
# score: 15
# breed: Ragamuffin
# temperament: Affectionate, Friendly, Gentle, Calm
# weight_kg: (4, 9)
# grooming: 3
# energy: 3
# vocalisation: 1
# hairless: no
# description: The Ragamuffin is calm, even tempered and gets along well with all family members. Changes in routine generally do not upset her. She is an ideal companion for those in apartments, and with children due to her patient nature.
# --------------------------------------------------------------------------------
# rank: 3
# score: 15
# breed: Ragdoll
# temperament: Affectionate, Friendly, Gentle, Quiet, Easygoing
# weight_kg: (5, 9)
# grooming: 2
# energy: 3
# vocalisation: 1
# hairless: no
# description: Ragdolls love their people, greeting them at the door, following them around the house, and leaping into a lap or snuggling in bed whenever given the chance. They are the epitome of a lap cat, enjoy being carried and collapsing into the arms of anyone who holds them.
# --------------------------------------------------------------------------------
# rank: 4
# score: 15
# breed: Selkirk Rex
# temperament: Active, Affectionate, Dependent, Gentle, Patient, Playful, Quiet, Social
# weight_kg: (3, 7)
# grooming: 2
# energy: 3
# vocalisation: 3
# hairless: no
# description: The Selkirk Rex is an incredibly patient, loving, and tolerant breed. The Selkirk also has a silly side and is sometimes described as clownish. She loves being a lap cat and will be happy to chat with you in a quiet voice if you talk to her.
# --------------------------------------------------------------------------------
# rank: 5
# score: 11
# breed: British Longhair
# temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social
# weight_kg: (4, 8)
# grooming: 5
# energy: 4
# vocalisation: 1
# hairless: no
# description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners ...
# ====================================================================================================
# QUERY: большая спокойная кошка
# --------------------------------------------------------------------------------
# rank: 1
# score: 20
# breed: British Shorthair
# temperament: Affectionate, Easy Going, Gentle, Loyal, Patient, calm
# weight_kg: (5, 9)
# grooming: 2
# energy: 2
# vocalisation: 1
# hairless: no
# description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will ...
# --------------------------------------------------------------------------------
# rank: 2
# score: 14
# breed: Ragamuffin
# temperament: Affectionate, Friendly, Gentle, Calm
# weight_kg: (4, 9)
# grooming: 3
# energy: 3
# vocalisation: 1
# hairless: no
# description: The Ragamuffin is calm, even tempered and gets along well with all family members. Changes in routine generally do not upset her. She is an ideal companion for those in apartments, and with children due to her patient nature.
# --------------------------------------------------------------------------------
# rank: 3
# score: 14
# breed: Ragdoll
# temperament: Affectionate, Friendly, Gentle, Quiet, Easygoing
# weight_kg: (5, 9)
# grooming: 2
# energy: 3
# vocalisation: 1
# hairless: no
# description: Ragdolls love their people, greeting them at the door, following them around the house, and leaping into a lap or snuggling in bed whenever given the chance. They are the epitome of a lap cat, enjoy being carried and collapsing into the arms of anyone who holds them.
# --------------------------------------------------------------------------------
# rank: 4
# score: 14
# breed: Selkirk Rex
# temperament: Active, Affectionate, Dependent, Gentle, Patient, Playful, Quiet, Social
# weight_kg: (3, 7)
# grooming: 2
# energy: 3
# vocalisation: 3
# hairless: no
# description: The Selkirk Rex is an incredibly patient, loving, and tolerant breed. The Selkirk also has a silly side and is sometimes described as clownish. She loves being a lap cat and will be happy to chat with you in a quiet voice if you talk to her.
# --------------------------------------------------------------------------------
# rank: 5
# score: 11
# breed: British Longhair
# temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social
# weight_kg: (4, 8)
# grooming: 5
# energy: 4
# vocalisation: 1
# hairless: no
# description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners ...
# ====================================================================================================
# QUERY: hairless cat care
# --------------------------------------------------------------------------------
# rank: 1
# score: 10
# breed: Donskoy
# temperament: Playful, affectionate, loyal, social
# weight_kg: (5, 6)
# grooming: 2
# energy: 4
# vocalisation: 2
# hairless: yes
# description: Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer th...
# --------------------------------------------------------------------------------
# rank: 2
# score: 10
# breed: Sphynx
# temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle
# weight_kg: (3, 5)
# grooming: 2
# energy: 3
# vocalisation: 5
# hairless: yes
# description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression.
# --------------------------------------------------------------------------------
# rank: 3
# score: 9
# breed: Bambino
# temperament: Affectionate, Lively, Friendly, Intelligent
# weight_kg: (2, 4)
# grooming: 1
# energy: 5
# vocalisation: 3
# hairless: yes
# description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members.
# --------------------------------------------------------------------------------
# rank: 4
# score: 5
# breed: British Longhair
# temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social
# weight_kg: (4, 8)
# grooming: 5
# energy: 4
# vocalisation: 1
# hairless: no
# description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners ...
# --------------------------------------------------------------------------------
# rank: 5
# score: 5
# breed: Chantilly-Tiffany
# temperament: Affectionate, Demanding, Interactive, Loyal
# weight_kg: (3, 5)
# grooming: 5
# energy: 4
# vocalisation: 5
# hairless: no
# description: The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of it...
# ====================================================================================================
# QUERY: как ухаживать за сфинксом
# --------------------------------------------------------------------------------
# rank: 1
# score: 0
# breed: Abyssinian
# temperament: Active, Energetic, Independent, Intelligent, Gentle
# weight_kg: (3, 5)
# grooming: 1
# energy: 5
# vocalisation: 1
# hairless: no
# description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals.
# --------------------------------------------------------------------------------
# rank: 2
# score: 0
# breed: Aegean
# temperament: Affectionate, Social, Intelligent, Playful, Active
# weight_kg: (3, 5)
# grooming: 3
# energy: 3
# vocalisation: 3
# hairless: no
# description: Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0
# breed: American Bobtail
# temperament: Intelligent, Interactive, Lively, Playful, Sensitive
# weight_kg: (3, 7)
# grooming: 1
# energy: 3
# vocalisation: 3
# hairless: no
# description: American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion.
# --------------------------------------------------------------------------------
# rank: 4
# score: 0
# breed: American Curl
# temperament: Affectionate, Curious, Intelligent, Interactive, Lively, Playful, Social
# weight_kg: (2, 5)
# grooming: 2
# energy: 3
# vocalisation: 3
# hairless: no
# description: Distinguished by truly unique ears that curl back in a graceful arc, offering an alert, perky, happily surprised expression, they cause people to break out into a big smile when viewing their first Curl. Curls are very people-oriented, faithful, affectionate soulmates, adjusting remarkably fast to o...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0
# breed: American Shorthair
# temperament: Active, Curious, Easy Going, Playful, Calm
# weight_kg: (4, 7)
# grooming: 1
# energy: 3
# vocalisation: 3
# hairless: no
# description: The American Shorthair is known for its longevity, robust health, good looks, sweet personality, and amiability with children, dogs, and other pets.
# ====================================================================================================
# QUERY: vocal intelligent cat
# --------------------------------------------------------------------------------
# rank: 1
# score: 11
# breed: Balinese
# temperament: Affectionate, Intelligent, Playful
# weight_kg: (2, 5)
# grooming: 3
# energy: 5
# vocalisation: 5
# hairless: no
# description: Balinese are curious, outgoing, intelligent cats with excellent communication skills. They are known for their chatty personalities and are always eager to tell you their views on life, love, and what you’ve served them for dinner.
# --------------------------------------------------------------------------------
# rank: 2
# score: 11
# breed: Bengal
# temperament: Alert, Agile, Energetic, Demanding, Intelligent
# weight_kg: (3, 7)
# grooming: 1
# energy: 5
# vocalisation: 5
# hairless: no
# description: Bengals are a lot of fun to live with, but they're definitely not the cat for everyone, or for first-time cat owners. Extremely intelligent, curious and active, they demand a lot of interaction and woe betide the owner who doesn't provide it.
# --------------------------------------------------------------------------------
# rank: 3
# score: 11
# breed: Bombay
# temperament: Affectionate, Dependent, Gentle, Intelligent, Playful
# weight_kg: (3, 5)
# grooming: 1
# energy: 3
# vocalisation: 5
# hairless: no
# description: The the golden eyes and the shiny black coa of the Bopmbay is absolutely striking. Likely to bond most with one family member, the Bombay will follow you from room to room and will almost always have something to say about what you are doing, loving attention and to be carried around, often on his c...
# --------------------------------------------------------------------------------
# rank: 4
# score: 11
# breed: Burmese
# temperament: Curious, Intelligent, Gentle, Social, Interactive, Playful, Lively
# weight_kg: (3, 5)
# grooming: 1
# energy: 4
# vocalisation: 5
# hairless: no
# description: Burmese love being with people, playing with them, and keeping them entertained. They crave close physical contact and abhor an empty lap. They will follow their humans from room to room, and sleep in bed with them, preferably under the covers, cuddled as close as possible. At play, they will turn a...
# --------------------------------------------------------------------------------
# rank: 5
# score: 11
# breed: Cheetoh
# temperament: Affectionate, Gentle, Intelligent, Social
# weight_kg: (4, 7)
# grooming: 1
# energy: 4
# vocalisation: 5
# hairless: no
# description: The Cheetoh has a super affectionate nature and real love for their human companions; they are intelligent with the ability to learn quickly. You can expect that a Cheetoh will be a fun-loving kitty who enjoys playing, running, and jumping through every room in your house.
# ====================================================================================================
# QUERY: разговорчивая умная кошка
# --------------------------------------------------------------------------------
# rank: 1
# score: 10
# breed: Balinese
# temperament: Affectionate, Intelligent, Playful
# weight_kg: (2, 5)
# grooming: 3
# energy: 5
# vocalisation: 5
# hairless: no
# description: Balinese are curious, outgoing, intelligent cats with excellent communication skills. They are known for their chatty personalities and are always eager to tell you their views on life, love, and what you’ve served them for dinner.
# --------------------------------------------------------------------------------
# rank: 2
# score: 10
# breed: Bengal
# temperament: Alert, Agile, Energetic, Demanding, Intelligent
# weight_kg: (3, 7)
# grooming: 1
# energy: 5
# vocalisation: 5
# hairless: no
# description: Bengals are a lot of fun to live with, but they're definitely not the cat for everyone, or for first-time cat owners. Extremely intelligent, curious and active, they demand a lot of interaction and woe betide the owner who doesn't provide it.
# --------------------------------------------------------------------------------
# rank: 3
# score: 10
# breed: Bombay
# temperament: Affectionate, Dependent, Gentle, Intelligent, Playful
# weight_kg: (3, 5)
# grooming: 1
# energy: 3
# vocalisation: 5
# hairless: no
# description: The the golden eyes and the shiny black coa of the Bopmbay is absolutely striking. Likely to bond most with one family member, the Bombay will follow you from room to room and will almost always have something to say about what you are doing, loving attention and to be carried around, often on his c...
# --------------------------------------------------------------------------------
# rank: 4
# score: 10
# breed: Burmese
# temperament: Curious, Intelligent, Gentle, Social, Interactive, Playful, Lively
# weight_kg: (3, 5)
# grooming: 1
# energy: 4
# vocalisation: 5
# hairless: no
# description: Burmese love being with people, playing with them, and keeping them entertained. They crave close physical contact and abhor an empty lap. They will follow their humans from room to room, and sleep in bed with them, preferably under the covers, cuddled as close as possible. At play, they will turn a...
# --------------------------------------------------------------------------------
# rank: 5
# score: 10
# breed: Chantilly-Tiffany
# temperament: Affectionate, Demanding, Interactive, Loyal
# weight_kg: (3, 5)
# grooming: 5
# energy: 4
# vocalisation: 5
# hairless: no
# description: The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of it...
# ====================================================================================================
# QUERY: long hair grooming
# --------------------------------------------------------------------------------
# rank: 1
# score: 5
# breed: British Longhair
# temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social
# weight_kg: (4, 8)
# grooming: 5
# energy: 4
# vocalisation: 1
# hairless: no
# description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners ...
# --------------------------------------------------------------------------------
# rank: 2
# score: 5
# breed: Chantilly-Tiffany
# temperament: Affectionate, Demanding, Interactive, Loyal
# weight_kg: (3, 5)
# grooming: 5
# energy: 4
# vocalisation: 5
# hairless: no
# description: The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of it...
# --------------------------------------------------------------------------------
# rank: 3
# score: 5
# breed: Himalayan
# temperament: Dependent, Gentle, Intelligent, Quiet, Social
# weight_kg: (3, 6)
# grooming: 5
# energy: 1
# vocalisation: 1
# hairless: no
# description: Calm and devoted, Himalayans make excellent companions, though they prefer a quieter home. They are playful in a sedate kind of way and enjoy having an assortment of toys. The Himalayan will stretch out next to you, sleep in your bed and even sit on your lap when she is in the mood.
# --------------------------------------------------------------------------------
# rank: 4
# score: 5
# breed: Persian
# temperament: Affectionate, loyal, Sedate, Quiet
# weight_kg: (4, 6)
# grooming: 5
# energy: 1
# vocalisation: 1
# hairless: no
# description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time.
# --------------------------------------------------------------------------------
# rank: 5
# score: 3
# breed: Donskoy
# temperament: Playful, affectionate, loyal, social
# weight_kg: (5, 6)
# grooming: 2
# energy: 4
# vocalisation: 2
# hairless: yes
# description: Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer th...
# ====================================================================================================
# QUERY: кошка с высоким уровнем ухода за шерстью
# --------------------------------------------------------------------------------
# rank: 1
# score: 5
# breed: British Longhair
# temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social
# weight_kg: (4, 8)
# grooming: 5
# energy: 4
# vocalisation: 1
# hairless: no
# description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners ...
# --------------------------------------------------------------------------------
# rank: 2
# score: 5
# breed: Chantilly-Tiffany
# temperament: Affectionate, Demanding, Interactive, Loyal
# weight_kg: (3, 5)
# grooming: 5
# energy: 4
# vocalisation: 5
# hairless: no
# description: The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of it...
# --------------------------------------------------------------------------------
# rank: 3
# score: 5
# breed: Himalayan
# temperament: Dependent, Gentle, Intelligent, Quiet, Social
# weight_kg: (3, 6)
# grooming: 5
# energy: 1
# vocalisation: 1
# hairless: no
# description: Calm and devoted, Himalayans make excellent companions, though they prefer a quieter home. They are playful in a sedate kind of way and enjoy having an assortment of toys. The Himalayan will stretch out next to you, sleep in your bed and even sit on your lap when she is in the mood.
# --------------------------------------------------------------------------------
# rank: 4
# score: 5
# breed: Persian
# temperament: Affectionate, loyal, Sedate, Quiet
# weight_kg: (4, 6)
# grooming: 5
# energy: 1
# vocalisation: 1
# hairless: no
# description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time.
# --------------------------------------------------------------------------------
# rank: 5
# score: 2
# breed: Aegean
# temperament: Affectionate, Social, Intelligent, Playful, Active
# weight_kg: (3, 5)
# grooming: 3
# energy: 3
# vocalisation: 3
# hairless: no
# description: Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can...

# %% [markdown]
# ## Hybrid retrieval v2: alias + structured fields
#
# Теперь собираем более правильную retrieval-стратегию:
#
# 1. Сначала ищем явное упоминание породы через aliases.
# 2. Если порода найдена — возвращаем профиль этой породы.
# 3. Если порода не найдена — используем structured scoring по CatAPI fields.
# 4. Если все scores равны 0 — не возвращаем случайную породу, а честно говорим, что подходящий контекст не найден.
#
# Это уже хороший baseline для backend до подключения embeddings.

# %%
chunk_by_breed = {
    chunk.get("breed_name"): chunk
    for chunk in chunks
}

profile_by_breed = {
    profile.get("breed_name"): profile
    for profile in profiles
}

print("Chunks by breed:", len(chunk_by_breed))
print("Profiles by breed:", len(profile_by_breed))

for breed in ["British Shorthair", "Maine Coon", "Sphynx", "Siamese", "Persian"]:
    print(breed, "→", breed in chunk_by_breed, breed in profile_by_breed)
# Out:
# Chunks by breed: 67
# Profiles by breed: 67
# British Shorthair → True True
# Maine Coon → True True
# Sphynx → True True
# Siamese → True True
# Persian → True True

# %%
def profile_to_chunk(profile: Dict[str, Any]) -> Optional[Dict[str, Any]]:
    breed_name = profile.get("breed_name")
    return chunk_by_breed.get(breed_name)


def hybrid_retrieve_v2(question: str, top_k: int = 5) -> Dict[str, Any]:
    detected_breed = detect_breed_alias(question)

    # 1. Alias exact breed retrieval
    if detected_breed:
        chunk = chunk_by_breed.get(detected_breed)

        if chunk:
            return {
                "strategy": "alias_exact_breed",
                "detected_breed": detected_breed,
                "results": [
                    {
                        "rank": 1,
                        "score": None,
                        "chunk": chunk,
                    }
                ],
                "warning": None,
            }

        return {
            "strategy": "alias_detected_but_chunk_missing",
            "detected_breed": detected_breed,
            "results": [],
            "warning": f"Breed detected as {detected_breed}, but chunk was not found.",
        }

    # 2. Structured retrieval fallback
    structured_results = structured_retrieve(question, top_k=top_k)

    converted_results = []
    for item in structured_results:
        score = item["score"]

        # Не возвращаем мусор с нулевым score
        if score <= 0:
            continue

        profile = item["profile"]
        chunk = profile_to_chunk(profile)

        if chunk is None:
            continue

        converted_results.append({
            "rank": len(converted_results) + 1,
            "score": score,
            "chunk": chunk,
        })

    if not converted_results:
        return {
            "strategy": "structured_no_match",
            "detected_breed": None,
            "results": [],
            "warning": "No relevant CatAPI context found with current retrieval rules.",
        }

    return {
        "strategy": "structured_fields",
        "detected_breed": None,
        "results": converted_results,
        "warning": None,
    }

# %%
def print_retrieval_result_v2(question: str, result: Dict[str, Any]):
    print("=" * 100)
    print("QUESTION:", question)
    print("STRATEGY:", result.get("strategy"))
    print("DETECTED BREED:", result.get("detected_breed"))

    if result.get("warning"):
        print("WARNING:", result["warning"])

    if not result.get("results"):
        print("No retrieved context.")
        return

    for item in result["results"]:
        chunk = item["chunk"]
        metadata = chunk.get("metadata", {}) or {}

        print("-" * 80)
        print("rank:", item["rank"])
        print("score:", item["score"])
        print("breed:", chunk.get("breed_name"))
        print("breed_id:", chunk.get("breed_id"))
        print("origin:", metadata.get("origin"))
        print("wikipedia_url:", metadata.get("wikipedia_url"))
        print("reference_image_id:", metadata.get("reference_image_id"))
        print("image_url:", metadata.get("image_url"))
        print("text:", preview_text(chunk.get("text", ""), 450))

# %%
hybrid_v2_queries = [
    "Чем британские котики отличаются от обычных?",
    "Расскажи про мейн куна",
    "Как ухаживать за сфинксом?",
    "Сиамская кошка разговорчивая и умная?",
    "Persian cat grooming",
    "large gentle cat",
    "большая спокойная кошка",
    "hairless cat care",
    "vocal intelligent cat",
    "разговорчивая умная кошка",
    "long hair grooming",
    "кошка с высоким уровнем ухода за шерстью",
    "какая кошка умеет чинить ноутбук?",
]

for q in hybrid_v2_queries:
    result = hybrid_retrieve_v2(q, top_k=5)
    print_retrieval_result_v2(q, result)
# Out:
# ====================================================================================================
# QUESTION: Чем британские котики отличаются от обычных?
# STRATEGY: alias_exact_breed
# DETECTED BREED: British Shorthair
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
# image_url: None
# text: Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good com...
# ====================================================================================================
# QUESTION: Расскажи про мейн куна
# STRATEGY: alias_exact_breed
# DETECTED BREED: Maine Coon
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Maine Coon
# breed_id: mcoo
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Maine_Coon
# reference_image_id: OOD3VXAQn
# image_url: None
# text: Breed name: Maine Coon Description: They are known for their size and luxurious long coat Maine Coons are considered a gentle giant. The good-natured and affable Maine Coon adapts well to many lifestyles and personalities. She likes being with people and has the habit of following them around, but isn’t needy. Most Maine Coons love water and they can be quite good swimmers. Temperament: Adaptable, Intelligent, Loving, Gentle, Independent Origin: ...
# ====================================================================================================
# QUESTION: Как ухаживать за сфинксом?
# STRATEGY: alias_exact_breed
# DETECTED BREED: Sphynx
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Sphynx
# breed_id: sphy
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Sphynx_(cat)
# reference_image_id: BDb8ZXb1v
# image_url: None
# text: Breed name: Sphynx Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression. Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle Origin: Canada Life span: 12 - 14 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 2 Energy lev...
# ====================================================================================================
# QUESTION: Сиамская кошка разговорчивая и умная?
# STRATEGY: alias_exact_breed
# DETECTED BREED: Siamese
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Siamese
# breed_id: siam
# origin: Thailand
# wikipedia_url: https://en.wikipedia.org/wiki/Siamese_(cat)
# reference_image_id: ai6Jps4sx
# image_url: None
# text: Breed name: Siamese Description: While Siamese cats are extremely fond of their people, they will follow you around and supervise your every move, being talkative and opinionated. They are a demanding and social cat, that do not like being left alone for long periods. Temperament: Active, Agile, Clever, Sociable, Loving, Energetic Origin: Thailand Life span: 12 - 15 years Weight: 4 - 7 kg (8 - 15 lb) Grooming level: 1 Energy level: 5 Health issue...
# ====================================================================================================
# QUESTION: Persian cat grooming
# STRATEGY: alias_exact_breed
# DETECTED BREED: Persian
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# image_url: None
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# ====================================================================================================
# QUESTION: large gentle cat
# STRATEGY: structured_fields
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 21
# breed: British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
# image_url: None
# text: Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good com...
# --------------------------------------------------------------------------------
# rank: 2
# score: 15
# breed: Ragamuffin
# breed_id: raga
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Ragamuffin_cat
# reference_image_id: SMuZx-bFM
# image_url: None
# text: Breed name: Ragamuffin Description: The Ragamuffin is calm, even tempered and gets along well with all family members. Changes in routine generally do not upset her. She is an ideal companion for those in apartments, and with children due to her patient nature. Temperament: Affectionate, Friendly, Gentle, Calm Origin: United States Life span: 12 - 16 years Weight: 4 - 9 kg (8 - 20 lb) Grooming level: 3 Energy level: 3 Health issues score: 3 Child...
# --------------------------------------------------------------------------------
# rank: 3
# score: 15
# breed: Ragdoll
# breed_id: ragd
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Ragdoll
# reference_image_id: oGefY4YoG
# image_url: None
# text: Breed name: Ragdoll Description: Ragdolls love their people, greeting them at the door, following them around the house, and leaping into a lap or snuggling in bed whenever given the chance. They are the epitome of a lap cat, enjoy being carried and collapsing into the arms of anyone who holds them. Temperament: Affectionate, Friendly, Gentle, Quiet, Easygoing Origin: United States Life span: 12 - 17 years Weight: 5 - 9 kg (12 - 20 lb) Grooming l...
# --------------------------------------------------------------------------------
# rank: 4
# score: 15
# breed: Selkirk Rex
# breed_id: srex
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Selkirk_Rex
# reference_image_id: II9dOZmrw
# image_url: None
# text: Breed name: Selkirk Rex Description: The Selkirk Rex is an incredibly patient, loving, and tolerant breed. The Selkirk also has a silly side and is sometimes described as clownish. She loves being a lap cat and will be happy to chat with you in a quiet voice if you talk to her.  Temperament: Active, Affectionate, Dependent, Gentle, Patient, Playful, Quiet, Social Origin: United States Life span: 14 - 15 years Weight: 3 - 7 kg (6 - 16 lb) Grooming...
# --------------------------------------------------------------------------------
# rank: 5
# score: 11
# breed: British Longhair
# breed_id: bslo
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Longhair
# reference_image_id: 7isAO4Cav
# image_url: None
# text: Breed name: British Longhair Description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up. Temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social ...
# ====================================================================================================
# QUESTION: большая спокойная кошка
# STRATEGY: structured_fields
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 20
# breed: British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
# image_url: None
# text: Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good com...
# --------------------------------------------------------------------------------
# rank: 2
# score: 14
# breed: Ragamuffin
# breed_id: raga
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Ragamuffin_cat
# reference_image_id: SMuZx-bFM
# image_url: None
# text: Breed name: Ragamuffin Description: The Ragamuffin is calm, even tempered and gets along well with all family members. Changes in routine generally do not upset her. She is an ideal companion for those in apartments, and with children due to her patient nature. Temperament: Affectionate, Friendly, Gentle, Calm Origin: United States Life span: 12 - 16 years Weight: 4 - 9 kg (8 - 20 lb) Grooming level: 3 Energy level: 3 Health issues score: 3 Child...
# --------------------------------------------------------------------------------
# rank: 3
# score: 14
# breed: Ragdoll
# breed_id: ragd
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Ragdoll
# reference_image_id: oGefY4YoG
# image_url: None
# text: Breed name: Ragdoll Description: Ragdolls love their people, greeting them at the door, following them around the house, and leaping into a lap or snuggling in bed whenever given the chance. They are the epitome of a lap cat, enjoy being carried and collapsing into the arms of anyone who holds them. Temperament: Affectionate, Friendly, Gentle, Quiet, Easygoing Origin: United States Life span: 12 - 17 years Weight: 5 - 9 kg (12 - 20 lb) Grooming l...
# --------------------------------------------------------------------------------
# rank: 4
# score: 14
# breed: Selkirk Rex
# breed_id: srex
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Selkirk_Rex
# reference_image_id: II9dOZmrw
# image_url: None
# text: Breed name: Selkirk Rex Description: The Selkirk Rex is an incredibly patient, loving, and tolerant breed. The Selkirk also has a silly side and is sometimes described as clownish. She loves being a lap cat and will be happy to chat with you in a quiet voice if you talk to her.  Temperament: Active, Affectionate, Dependent, Gentle, Patient, Playful, Quiet, Social Origin: United States Life span: 14 - 15 years Weight: 3 - 7 kg (6 - 16 lb) Grooming...
# --------------------------------------------------------------------------------
# rank: 5
# score: 11
# breed: British Longhair
# breed_id: bslo
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Longhair
# reference_image_id: 7isAO4Cav
# image_url: None
# text: Breed name: British Longhair Description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up. Temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social ...
# ====================================================================================================
# QUESTION: hairless cat care
# STRATEGY: alias_exact_breed
# DETECTED BREED: Sphynx
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Sphynx
# breed_id: sphy
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Sphynx_(cat)
# reference_image_id: BDb8ZXb1v
# image_url: None
# text: Breed name: Sphynx Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression. Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle Origin: Canada Life span: 12 - 14 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 2 Energy lev...
# ====================================================================================================
# QUESTION: vocal intelligent cat
# STRATEGY: structured_fields
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 11
# breed: Balinese
# breed_id: bali
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Balinese_(cat)
# reference_image_id: 13MkvUreZ
# image_url: None
# text: Breed name: Balinese Description: Balinese are curious, outgoing, intelligent cats with excellent communication skills. They are known for their chatty personalities and are always eager to tell you their views on life, love, and what you’ve served them for dinner.  Temperament: Affectionate, Intelligent, Playful Origin: United States Life span: 10 - 15 years Weight: 2 - 5 kg (4 - 10 lb) Grooming level: 3 Energy level: 5 Health issues score: 3 Ch...
# --------------------------------------------------------------------------------
# rank: 2
# score: 11
# breed: Bengal
# breed_id: beng
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bengal_(cat)
# reference_image_id: O3btzLlsO
# image_url: None
# text: Breed name: Bengal Description: Bengals are a lot of fun to live with, but they're definitely not the cat for everyone, or for first-time cat owners. Extremely intelligent, curious and active, they demand a lot of interaction and woe betide the owner who doesn't provide it. Temperament: Alert, Agile, Energetic, Demanding, Intelligent Origin: United States Life span: 12 - 15 years Weight: 3 - 7 kg (6 - 12 lb) Grooming level: 1 Energy level: 5 Heal...
# --------------------------------------------------------------------------------
# rank: 3
# score: 11
# breed: Bombay
# breed_id: bomb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bombay_(cat)
# reference_image_id: 5iYq9NmT1
# image_url: None
# text: Breed name: Bombay Description: The the golden eyes and the shiny black coa of the Bopmbay is absolutely striking. Likely to bond most with one family member, the Bombay will follow you from room to room and will almost always have something to say about what you are doing, loving attention and to be carried around, often on his caregiver's shoulder. Temperament: Affectionate, Dependent, Gentle, Intelligent, Playful Origin: United States Life spa...
# --------------------------------------------------------------------------------
# rank: 4
# score: 11
# breed: Burmese
# breed_id: bure
# origin: Burma
# wikipedia_url: https://en.wikipedia.org/wiki/Burmese_(cat)
# reference_image_id: 4lXnnfxac
# image_url: None
# text: Breed name: Burmese Description: Burmese love being with people, playing with them, and keeping them entertained. They crave close physical contact and abhor an empty lap. They will follow their humans from room to room, and sleep in bed with them, preferably under the covers, cuddled as close as possible. At play, they will turn around to see if their human is watching and being entertained by their crazy antics. Temperament: Curious, Intelligen...
# --------------------------------------------------------------------------------
# rank: 5
# score: 11
# breed: Cheetoh
# breed_id: chee
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bengal_cat#Cheetoh
# reference_image_id: IFXsxmXLm
# image_url: None
# text: Breed name: Cheetoh Description: The Cheetoh has a super affectionate nature and real love for their human companions; they are intelligent with the ability to learn quickly. You can expect that a Cheetoh will be a fun-loving kitty who enjoys playing, running, and jumping through every room in your house. Temperament: Affectionate, Gentle, Intelligent, Social Origin: United States Life span: 12 - 14 years Weight: 4 - 7 kg (8 - 15 lb) Grooming lev...
# ====================================================================================================
# QUESTION: разговорчивая умная кошка
# STRATEGY: structured_fields
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 10
# breed: Balinese
# breed_id: bali
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Balinese_(cat)
# reference_image_id: 13MkvUreZ
# image_url: None
# text: Breed name: Balinese Description: Balinese are curious, outgoing, intelligent cats with excellent communication skills. They are known for their chatty personalities and are always eager to tell you their views on life, love, and what you’ve served them for dinner.  Temperament: Affectionate, Intelligent, Playful Origin: United States Life span: 10 - 15 years Weight: 2 - 5 kg (4 - 10 lb) Grooming level: 3 Energy level: 5 Health issues score: 3 Ch...
# --------------------------------------------------------------------------------
# rank: 2
# score: 10
# breed: Bengal
# breed_id: beng
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bengal_(cat)
# reference_image_id: O3btzLlsO
# image_url: None
# text: Breed name: Bengal Description: Bengals are a lot of fun to live with, but they're definitely not the cat for everyone, or for first-time cat owners. Extremely intelligent, curious and active, they demand a lot of interaction and woe betide the owner who doesn't provide it. Temperament: Alert, Agile, Energetic, Demanding, Intelligent Origin: United States Life span: 12 - 15 years Weight: 3 - 7 kg (6 - 12 lb) Grooming level: 1 Energy level: 5 Heal...
# --------------------------------------------------------------------------------
# rank: 3
# score: 10
# breed: Bombay
# breed_id: bomb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bombay_(cat)
# reference_image_id: 5iYq9NmT1
# image_url: None
# text: Breed name: Bombay Description: The the golden eyes and the shiny black coa of the Bopmbay is absolutely striking. Likely to bond most with one family member, the Bombay will follow you from room to room and will almost always have something to say about what you are doing, loving attention and to be carried around, often on his caregiver's shoulder. Temperament: Affectionate, Dependent, Gentle, Intelligent, Playful Origin: United States Life spa...
# --------------------------------------------------------------------------------
# rank: 4
# score: 10
# breed: Burmese
# breed_id: bure
# origin: Burma
# wikipedia_url: https://en.wikipedia.org/wiki/Burmese_(cat)
# reference_image_id: 4lXnnfxac
# image_url: None
# text: Breed name: Burmese Description: Burmese love being with people, playing with them, and keeping them entertained. They crave close physical contact and abhor an empty lap. They will follow their humans from room to room, and sleep in bed with them, preferably under the covers, cuddled as close as possible. At play, they will turn around to see if their human is watching and being entertained by their crazy antics. Temperament: Curious, Intelligen...
# --------------------------------------------------------------------------------
# rank: 5
# score: 10
# breed: Chantilly-Tiffany
# breed_id: ctif
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Chantilly-Tiffany
# reference_image_id: TR-5nAd_S
# image_url: None
# text: Breed name: Chantilly-Tiffany Description: The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of its loved one. This quality makes the Tiffany an ideal traveling companion, and an ideal house companion for ...
# ====================================================================================================
# QUESTION: long hair grooming
# STRATEGY: structured_fields
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 5
# breed: British Longhair
# breed_id: bslo
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Longhair
# reference_image_id: 7isAO4Cav
# image_url: None
# text: Breed name: British Longhair Description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up. Temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social ...
# --------------------------------------------------------------------------------
# rank: 2
# score: 5
# breed: Chantilly-Tiffany
# breed_id: ctif
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Chantilly-Tiffany
# reference_image_id: TR-5nAd_S
# image_url: None
# text: Breed name: Chantilly-Tiffany Description: The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of its loved one. This quality makes the Tiffany an ideal traveling companion, and an ideal house companion for ...
# --------------------------------------------------------------------------------
# rank: 3
# score: 5
# breed: Himalayan
# breed_id: hima
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Himalayan_(cat)
# reference_image_id: CDhOtM-Ig
# image_url: None
# text: Breed name: Himalayan Description: Calm and devoted, Himalayans make excellent companions, though they prefer a quieter home. They are playful in a sedate kind of way and enjoy having an assortment of toys. The Himalayan will stretch out next to you, sleep in your bed and even sit on your lap when she is in the mood. Temperament: Dependent, Gentle, Intelligent, Quiet, Social Origin: United States Life span: 9 - 15 years Weight: 3 - 6 kg (7 - 14 l...
# --------------------------------------------------------------------------------
# rank: 4
# score: 5
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# image_url: None
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# --------------------------------------------------------------------------------
# rank: 5
# score: 3
# breed: Donskoy
# breed_id: dons
# origin: Russia
# wikipedia_url: https://en.wikipedia.org/wiki/Donskoy_(cat)
# reference_image_id: 3KG57GfMW
# image_url: None
# text: Breed name: Donskoy Description: Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer the less hair they have. Temperament: Playful, affectionate, loyal, social Origin: Russia Life span: 12 - 15 years Weig...
# ====================================================================================================
# QUESTION: кошка с высоким уровнем ухода за шерстью
# STRATEGY: structured_fields
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 5
# breed: British Longhair
# breed_id: bslo
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Longhair
# reference_image_id: 7isAO4Cav
# image_url: None
# text: Breed name: British Longhair Description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up. Temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social ...
# --------------------------------------------------------------------------------
# rank: 2
# score: 5
# breed: Chantilly-Tiffany
# breed_id: ctif
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Chantilly-Tiffany
# reference_image_id: TR-5nAd_S
# image_url: None
# text: Breed name: Chantilly-Tiffany Description: The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of its loved one. This quality makes the Tiffany an ideal traveling companion, and an ideal house companion for ...
# --------------------------------------------------------------------------------
# rank: 3
# score: 5
# breed: Himalayan
# breed_id: hima
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Himalayan_(cat)
# reference_image_id: CDhOtM-Ig
# image_url: None
# text: Breed name: Himalayan Description: Calm and devoted, Himalayans make excellent companions, though they prefer a quieter home. They are playful in a sedate kind of way and enjoy having an assortment of toys. The Himalayan will stretch out next to you, sleep in your bed and even sit on your lap when she is in the mood. Temperament: Dependent, Gentle, Intelligent, Quiet, Social Origin: United States Life span: 9 - 15 years Weight: 3 - 6 kg (7 - 14 l...
# --------------------------------------------------------------------------------
# rank: 4
# score: 5
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# image_url: None
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# --------------------------------------------------------------------------------
# rank: 5
# score: 2
# breed: Aegean
# breed_id: aege
# origin: Greece
# wikipedia_url: https://en.wikipedia.org/wiki/Aegean_cat
# reference_image_id: ozEvzdVM-
# image_url: None
# text: Breed name: Aegean Description: Native to the Greek islands known as the Cyclades in the Aegean Sea, these are natural cats, meaning they developed without humans getting involved in their breeding. As a breed, Aegean Cats are rare, although they are numerous on their home islands. They are generally friendly toward people and can be excellent cats for families with children. Temperament: Affectionate, Social, Intelligent, Playful, Active Origin:...
# ====================================================================================================
# QUESTION: какая кошка умеет чинить ноутбук?
# STRATEGY: structured_no_match
# DETECTED BREED: None
# WARNING: No relevant CatAPI context found with current retrieval rules.
# No retrieved context.

# %% [markdown]
# ## Вывод после Hybrid retrieval v2
#
# Теперь retrieval работает намного лучше:
#
# - запросы с явной породой обрабатываются через alias detection;
# - описательные запросы обрабатываются через structured CatAPI fields;
# - если совпадений нет, система не возвращает случайную породу;
# - retrieved context явно виден до генерации ответа.
#
# Это хороший baseline для приложения.
#
# Embeddings и ChromaDB можно добавить позже, но уже сейчас понятно, что для русскоязычного сервиса полезна гибридная схема:
#
# `breed alias detection → structured retrieval → vector retrieval`

# %%
def build_rag_prompt_v2(question: str, retrieved_result: Dict[str, Any]) -> str:
    context_blocks = []

    for item in retrieved_result.get("results", []):
        chunk = item["chunk"]
        metadata = chunk.get("metadata", {}) or {}

        block = f"""
[Context chunk]
Rank: {item.get("rank")}
Retrieval strategy: {retrieved_result.get("strategy")}
Retrieval score: {item.get("score")}
Breed: {chunk.get("breed_name")}
Breed ID: {chunk.get("breed_id")}
Origin: {metadata.get("origin")}
Wikipedia URL: {metadata.get("wikipedia_url")}
Reference image ID: {metadata.get("reference_image_id")}
Image URL: {metadata.get("image_url")}

Text:
{chunk.get("text")}
""".strip()

        context_blocks.append(block)

    if context_blocks:
        context_text = "\n\n---\n\n".join(context_blocks)
    else:
        context_text = "No relevant CatAPI context was retrieved."

    prompt = f"""
SYSTEM INSTRUCTION:
{SYSTEM_INSTRUCTION}

RETRIEVED CONTEXT:
{context_text}

USER QUESTION:
{question}

ANSWER:
""".strip()

    return prompt

# %%
prompt_questions = [
    "Чем британские котики отличаются от обычных?",
    "Какая кошка большая, спокойная и ласковая?",
    "Какая кошка разговорчивая и умная?",
    "Как ухаживать за сфинксом?",
    "Какая кошка умеет чинить ноутбук?",
]

for q in prompt_questions:
    print("=" * 120)
    print("QUESTION:", q)

    retrieved = hybrid_retrieve_v2(q, top_k=3)
    print("STRATEGY:", retrieved["strategy"])
    print("DETECTED BREED:", retrieved["detected_breed"])
    print("WARNING:", retrieved["warning"])

    print("\nPROMPT:")
    print(build_rag_prompt_v2(q, retrieved))
    print()
# Out:
# ========================================================================================================================
# QUESTION: Чем британские котики отличаются от обычных?
# STRATEGY: alias_exact_breed
# DETECTED BREED: British Shorthair
# WARNING: None
#
# PROMPT:
# SYSTEM INSTRUCTION:
# Ты — дружелюбный ассистент-консультант по породам кошек.
#
# Отвечай на русском языке.
# Используй только факты из retrieved context.
# Если информации мало, честно скажи, что данных недостаточно.
# Не давай категоричных медицинских советов.
# Если вопрос касается здоровья, мягко посоветуй обратиться к ветеринару.
#
# RETRIEVED CONTEXT:
# [Context chunk]
# Rank: 1
# Retrieval strategy: alias_exact_breed
# Retrieval score: None
# Breed: British Shorthair
# Breed ID: bsho
# Origin: United Kingdom
# Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
# Reference image ID: s4wQfYoEk
# Image URL: None
#
# Text:
# Breed name: British Shorthair
# Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people.
# Temperament: Affectionate, Easy Going, Gentle, Loyal, Patient, calm
# Origin: United Kingdom
# Life span: 12 - 17 years
# Weight: 5 - 9 kg (12 - 20 lb)
# Grooming level: 2
# Energy level: 2
# Health issues score: 2
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 2
# Intelligence score: 3
# Hairless: no
# Shedding level: 4
# Social needs score: 3
# Vocalisation score: 1
# Hypoallergenic: 0
# Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
#
# USER QUESTION:
# Чем британские котики отличаются от обычных?
#
# ANSWER:
#
# ========================================================================================================================
# QUESTION: Какая кошка большая, спокойная и ласковая?
# STRATEGY: structured_fields
# DETECTED BREED: None
# WARNING: None
#
# PROMPT:
# SYSTEM INSTRUCTION:
# Ты — дружелюбный ассистент-консультант по породам кошек.
#
# Отвечай на русском языке.
# Используй только факты из retrieved context.
# Если информации мало, честно скажи, что данных недостаточно.
# Не давай категоричных медицинских советов.
# Если вопрос касается здоровья, мягко посоветуй обратиться к ветеринару.
#
# RETRIEVED CONTEXT:
# [Context chunk]
# Rank: 1
# Retrieval strategy: structured_fields
# Retrieval score: 20
# Breed: British Shorthair
# Breed ID: bsho
# Origin: United Kingdom
# Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
# Reference image ID: s4wQfYoEk
# Image URL: None
#
# Text:
# Breed name: British Shorthair
# Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people.
# Temperament: Affectionate, Easy Going, Gentle, Loyal, Patient, calm
# Origin: United Kingdom
# Life span: 12 - 17 years
# Weight: 5 - 9 kg (12 - 20 lb)
# Grooming level: 2
# Energy level: 2
# Health issues score: 2
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 2
# Intelligence score: 3
# Hairless: no
# Shedding level: 4
# Social needs score: 3
# Vocalisation score: 1
# Hypoallergenic: 0
# Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
#
# ---
#
# [Context chunk]
# Rank: 2
# Retrieval strategy: structured_fields
# Retrieval score: 14
# Breed: Ragamuffin
# Breed ID: raga
# Origin: United States
# Wikipedia URL: https://en.wikipedia.org/wiki/Ragamuffin_cat
# Reference image ID: SMuZx-bFM
# Image URL: None
#
# Text:
# Breed name: Ragamuffin
# Description: The Ragamuffin is calm, even tempered and gets along well with all family members. Changes in routine generally do not upset her. She is an ideal companion for those in apartments, and with children due to her patient nature.
# Temperament: Affectionate, Friendly, Gentle, Calm
# Origin: United States
# Life span: 12 - 16 years
# Weight: 4 - 9 kg (8 - 20 lb)
# Grooming level: 3
# Energy level: 3
# Health issues score: 3
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 5
# Intelligence score: 5
# Hairless: no
# Shedding level: 3
# Social needs score: 3
# Vocalisation score: 1
# Hypoallergenic: 0
# Wikipedia URL: https://en.wikipedia.org/wiki/Ragamuffin_cat
#
# ---
#
# [Context chunk]
# Rank: 3
# Retrieval strategy: structured_fields
# Retrieval score: 14
# Breed: Ragdoll
# Breed ID: ragd
# Origin: United States
# Wikipedia URL: https://en.wikipedia.org/wiki/Ragdoll
# Reference image ID: oGefY4YoG
# Image URL: None
#
# Text:
# Breed name: Ragdoll
# Description: Ragdolls love their people, greeting them at the door, following them around the house, and leaping into a lap or snuggling in bed whenever given the chance. They are the epitome of a lap cat, enjoy being carried and collapsing into the arms of anyone who holds them.
# Temperament: Affectionate, Friendly, Gentle, Quiet, Easygoing
# Origin: United States
# Life span: 12 - 17 years
# Weight: 5 - 9 kg (12 - 20 lb)
# Grooming level: 2
# Energy level: 3
# Health issues score: 3
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 3
# Intelligence score: 3
# Hairless: no
# Shedding level: 3
# Social needs score: 5
# Vocalisation score: 1
# Hypoallergenic: 0
# Wikipedia URL: https://en.wikipedia.org/wiki/Ragdoll
#
# USER QUESTION:
# Какая кошка большая, спокойная и ласковая?
#
# ANSWER:
#
# ========================================================================================================================
# QUESTION: Какая кошка разговорчивая и умная?
# STRATEGY: structured_fields
# DETECTED BREED: None
# WARNING: None
#
# PROMPT:
# SYSTEM INSTRUCTION:
# Ты — дружелюбный ассистент-консультант по породам кошек.
#
# Отвечай на русском языке.
# Используй только факты из retrieved context.
# Если информации мало, честно скажи, что данных недостаточно.
# Не давай категоричных медицинских советов.
# Если вопрос касается здоровья, мягко посоветуй обратиться к ветеринару.
#
# RETRIEVED CONTEXT:
# [Context chunk]
# Rank: 1
# Retrieval strategy: structured_fields
# Retrieval score: 10
# Breed: Balinese
# Breed ID: bali
# Origin: United States
# Wikipedia URL: https://en.wikipedia.org/wiki/Balinese_(cat)
# Reference image ID: 13MkvUreZ
# Image URL: None
#
# Text:
# Breed name: Balinese
# Description: Balinese are curious, outgoing, intelligent cats with excellent communication skills. They are known for their chatty personalities and are always eager to tell you their views on life, love, and what you’ve served them for dinner.
# Temperament: Affectionate, Intelligent, Playful
# Origin: United States
# Life span: 10 - 15 years
# Weight: 2 - 5 kg (4 - 10 lb)
# Grooming level: 3
# Energy level: 5
# Health issues score: 3
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 5
# Intelligence score: 5
# Hairless: no
# Shedding level: 3
# Social needs score: 5
# Vocalisation score: 5
# Hypoallergenic: 1
# Wikipedia URL: https://en.wikipedia.org/wiki/Balinese_(cat)
#
# ---
#
# [Context chunk]
# Rank: 2
# Retrieval strategy: structured_fields
# Retrieval score: 10
# Breed: Bengal
# Breed ID: beng
# Origin: United States
# Wikipedia URL: https://en.wikipedia.org/wiki/Bengal_(cat)
# Reference image ID: O3btzLlsO
# Image URL: None
#
# Text:
# Breed name: Bengal
# Description: Bengals are a lot of fun to live with, but they're definitely not the cat for everyone, or for first-time cat owners. Extremely intelligent, curious and active, they demand a lot of interaction and woe betide the owner who doesn't provide it.
# Temperament: Alert, Agile, Energetic, Demanding, Intelligent
# Origin: United States
# Life span: 12 - 15 years
# Weight: 3 - 7 kg (6 - 12 lb)
# Grooming level: 1
# Energy level: 5
# Health issues score: 3
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 3
# Intelligence score: 5
# Hairless: no
# Shedding level: 3
# Social needs score: 5
# Vocalisation score: 5
# Hypoallergenic: 1
# Wikipedia URL: https://en.wikipedia.org/wiki/Bengal_(cat)
#
# ---
#
# [Context chunk]
# Rank: 3
# Retrieval strategy: structured_fields
# Retrieval score: 10
# Breed: Bombay
# Breed ID: bomb
# Origin: United States
# Wikipedia URL: https://en.wikipedia.org/wiki/Bombay_(cat)
# Reference image ID: 5iYq9NmT1
# Image URL: None
#
# Text:
# Breed name: Bombay
# Description: The the golden eyes and the shiny black coa of the Bopmbay is absolutely striking. Likely to bond most with one family member, the Bombay will follow you from room to room and will almost always have something to say about what you are doing, loving attention and to be carried around, often on his caregiver's shoulder.
# Temperament: Affectionate, Dependent, Gentle, Intelligent, Playful
# Origin: United States
# Life span: 12 - 16 years
# Weight: 3 - 5 kg (6 - 11 lb)
# Grooming level: 1
# Energy level: 3
# Health issues score: 3
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 4
# Intelligence score: 5
# Hairless: no
# Shedding level: 3
# Social needs score: 4
# Vocalisation score: 5
# Hypoallergenic: 0
# Wikipedia URL: https://en.wikipedia.org/wiki/Bombay_(cat)
#
# USER QUESTION:
# Какая кошка разговорчивая и умная?
#
# ANSWER:
#
# ========================================================================================================================
# QUESTION: Как ухаживать за сфинксом?
# STRATEGY: alias_exact_breed
# DETECTED BREED: Sphynx
# WARNING: None
#
# PROMPT:
# SYSTEM INSTRUCTION:
# Ты — дружелюбный ассистент-консультант по породам кошек.
#
# Отвечай на русском языке.
# Используй только факты из retrieved context.
# Если информации мало, честно скажи, что данных недостаточно.
# Не давай категоричных медицинских советов.
# Если вопрос касается здоровья, мягко посоветуй обратиться к ветеринару.
#
# RETRIEVED CONTEXT:
# [Context chunk]
# Rank: 1
# Retrieval strategy: alias_exact_breed
# Retrieval score: None
# Breed: Sphynx
# Breed ID: sphy
# Origin: Canada
# Wikipedia URL: https://en.wikipedia.org/wiki/Sphynx_(cat)
# Reference image ID: BDb8ZXb1v
# Image URL: None
#
# Text:
# Breed name: Sphynx
# Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression.
# Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle
# Origin: Canada
# Life span: 12 - 14 years
# Weight: 3 - 5 kg (6 - 12 lb)
# Grooming level: 2
# Energy level: 3
# Health issues score: 4
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 5
# Intelligence score: 5
# Hairless: yes
# Shedding level: 1
# Social needs score: 5
# Vocalisation score: 5
# Hypoallergenic: 1
# Wikipedia URL: https://en.wikipedia.org/wiki/Sphynx_(cat)
#
# USER QUESTION:
# Как ухаживать за сфинксом?
#
# ANSWER:
#
# ========================================================================================================================
# QUESTION: Какая кошка умеет чинить ноутбук?
# STRATEGY: structured_no_match
# DETECTED BREED: None
# WARNING: No relevant CatAPI context found with current retrieval rules.
#
# PROMPT:
# SYSTEM INSTRUCTION:
# Ты — дружелюбный ассистент-консультант по породам кошек.
#
# Отвечай на русском языке.
# Используй только факты из retrieved context.
# Если информации мало, честно скажи, что данных недостаточно.
# Не давай категоричных медицинских советов.
# Если вопрос касается здоровья, мягко посоветуй обратиться к ветеринару.
#
# RETRIEVED CONTEXT:
# No relevant CatAPI context was retrieved.
#
# USER QUESTION:
# Какая кошка умеет чинить ноутбук?
#
# ANSWER:

# %%
# Уберём слишком широкий alias.
# "hairless" — это не конкретная порода, а признак.
# Поэтому такие запросы лучше обрабатывать через structured retrieval.

BREED_ALIASES.pop("hairless", None)

for q in [
    "hairless cat care",
    "Sphynx care",
    "как ухаживать за сфинксом",
]:
    print(q, "→", detect_breed_alias(q))
# Out:
# hairless cat care → None
# Sphynx care → Sphynx
# как ухаживать за сфинксом → Sphynx

# %%
for q in [
    "hairless cat care",
    "hairless friendly cat",
    "как ухаживать за сфинксом",
]:
    result = hybrid_retrieve_v2(q, top_k=5)
    print_retrieval_result_v2(q, result)
# Out:
# ====================================================================================================
# QUESTION: hairless cat care
# STRATEGY: structured_fields
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 10
# breed: Donskoy
# breed_id: dons
# origin: Russia
# wikipedia_url: https://en.wikipedia.org/wiki/Donskoy_(cat)
# reference_image_id: 3KG57GfMW
# image_url: None
# text: Breed name: Donskoy Description: Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer the less hair they have. Temperament: Playful, affectionate, loyal, social Origin: Russia Life span: 12 - 15 years Weig...
# --------------------------------------------------------------------------------
# rank: 2
# score: 10
# breed: Sphynx
# breed_id: sphy
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Sphynx_(cat)
# reference_image_id: BDb8ZXb1v
# image_url: None
# text: Breed name: Sphynx Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression. Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle Origin: Canada Life span: 12 - 14 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 2 Energy lev...
# --------------------------------------------------------------------------------
# rank: 3
# score: 9
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# image_url: None
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 4
# score: 5
# breed: British Longhair
# breed_id: bslo
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Longhair
# reference_image_id: 7isAO4Cav
# image_url: None
# text: Breed name: British Longhair Description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up. Temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social ...
# --------------------------------------------------------------------------------
# rank: 5
# score: 5
# breed: Chantilly-Tiffany
# breed_id: ctif
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Chantilly-Tiffany
# reference_image_id: TR-5nAd_S
# image_url: None
# text: Breed name: Chantilly-Tiffany Description: The Chantilly is a devoted companion and prefers company to being left alone. While the Chantilly is not demanding, she will "chirp" and "talk" as if having a conversation. This breed is affectionate, with a sweet temperament. It can stay still for extended periods, happily lounging in the lap of its loved one. This quality makes the Tiffany an ideal traveling companion, and an ideal house companion for ...
# ====================================================================================================
# QUESTION: hairless friendly cat
# STRATEGY: structured_fields
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 14
# breed: Sphynx
# breed_id: sphy
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Sphynx_(cat)
# reference_image_id: BDb8ZXb1v
# image_url: None
# text: Breed name: Sphynx Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression. Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle Origin: Canada Life span: 12 - 14 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 2 Energy lev...
# --------------------------------------------------------------------------------
# rank: 2
# score: 13
# breed: Donskoy
# breed_id: dons
# origin: Russia
# wikipedia_url: https://en.wikipedia.org/wiki/Donskoy_(cat)
# reference_image_id: 3KG57GfMW
# image_url: None
# text: Breed name: Donskoy Description: Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer the less hair they have. Temperament: Playful, affectionate, loyal, social Origin: Russia Life span: 12 - 15 years Weig...
# --------------------------------------------------------------------------------
# rank: 3
# score: 12
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# image_url: None
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 4
# score: 8
# breed: Australian Mist
# breed_id: amis
# origin: Australia
# wikipedia_url: https://en.wikipedia.org/wiki/Australian_Mist
# reference_image_id: _6x-3TiCA
# image_url: None
# text: Breed name: Australian Mist Description: The Australian Mist thrives on human companionship. Tolerant of even the youngest of children, these friendly felines enjoy playing games and being part of the hustle and bustle of a busy household. They make entertaining companions for people of all ages, and are happy to remain indoors between dusk and dawn or to be wholly indoor pets. Temperament: Lively, Social, Fun-loving, Relaxed, Affectionate Origin...
# --------------------------------------------------------------------------------
# rank: 5
# score: 8
# breed: Burmilla
# breed_id: buri
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/Burmilla
# reference_image_id: jvg3XfEdC
# image_url: None
# text: Breed name: Burmilla Description: The Burmilla is a fairly placid cat. She tends to be an easy cat to get along with, requiring minimal care. The Burmilla is affectionate and sweet and makes a good companion, the Burmilla is an ideal companion to while away a lonely evening. Loyal, devoted, and affectionate, this cat will stay by its owner, always keeping them company. Temperament: Easy Going, Friendly, Intelligent, Lively, Playful, Social Origin...
# ====================================================================================================
# QUESTION: как ухаживать за сфинксом
# STRATEGY: alias_exact_breed
# DETECTED BREED: Sphynx
# --------------------------------------------------------------------------------
# rank: 1
# score: None
# breed: Sphynx
# breed_id: sphy
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Sphynx_(cat)
# reference_image_id: BDb8ZXb1v
# image_url: None
# text: Breed name: Sphynx Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression. Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle Origin: Canada Life span: 12 - 14 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 2 Energy lev...

# %% [markdown]
# ## Baseline RAG conclusions
#
# На этом этапе у нас есть рабочий baseline retrieval без embeddings и ChromaDB.
#
# Что работает хорошо:
#
# - если пользователь явно называет породу, срабатывает `alias_exact_breed`;
# - если пользователь описывает желаемые признаки, срабатывает `structured_fields`;
# - если вопрос не относится к породам кошек, система не возвращает случайный chunk;
# - retrieved context явно виден до генерации ответа;
# - final RAG prompt можно проверить глазами.
#
# Это уже полезная RAG-архитектура:
#
# `question → breed alias / structured retrieval → retrieved context → prompt → answer`
#
# Ограничения:
#
# - structured rules написаны руками;
# - semantic similarity пока не используется;
# - русские описательные запросы требуют ручной поддержки словарей;
# - CatAPI даёт ограниченное описание пород;
# - image_url пока пустой, но есть reference_image_id.
#
# Следующий слой: попробовать embeddings in memory без ChromaDB.

# %% [markdown]
# ## Optional: semantic retrieval with embeddings
#
# Теперь попробуем semantic retrieval без ChromaDB.
#
# Мы не строим persistent index и не используем vector database.
#
# Идея:
#
# 1. Загружаем embedding model.
# 2. Считаем embeddings для 67 chunks.
# 3. Считаем embedding для query.
# 4. Ищем chunks с максимальной cosine similarity.
#
# Если `sentence-transformers` не работает в окружении, эту часть можно пропустить.

# %%
import sys
import platform

print("Python:", sys.version)
print("Platform:", platform.platform())

try:
    import numpy as np
    print("NumPy:", np.__version__)
except Exception as e:
    print("NumPy import failed:", repr(e))

try:
    import torch
    print("Torch:", torch.__version__)
    print("CUDA available:", torch.cuda.is_available())
except Exception as e:
    print("Torch import failed:", repr(e))

try:
    import transformers
    print("Transformers:", transformers.__version__)
except Exception as e:
    print("Transformers import failed:", repr(e))
# Out:
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Platform: Linux-6.12.90+-x86_64-with-glibc2.35
# NumPy: 2.0.2
# Torch: 2.10.0+cpu
# CUDA available: False
# Transformers: 5.0.0

# %%
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel

MODEL_NAME = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME).to(device)
model.eval()

print("Loaded model:", MODEL_NAME)
# Out:
# Device: cpu
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loaded model: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2

# %%
def mean_pooling(model_output, attention_mask):
    """
    Mean pooling с учётом attention mask.
    Берём token embeddings и усредняем только реальные токены, не padding.
    """
    token_embeddings = model_output[0]
    input_mask_expanded = (
        attention_mask
        .unsqueeze(-1)
        .expand(token_embeddings.size())
        .float()
    )

    summed = torch.sum(token_embeddings * input_mask_expanded, dim=1)
    counts = torch.clamp(input_mask_expanded.sum(dim=1), min=1e-9)

    return summed / counts


def l2_normalize(x: np.ndarray) -> np.ndarray:
    norms = np.linalg.norm(x, axis=1, keepdims=True)
    return x / np.clip(norms, 1e-12, None)


def embed_texts(texts: List[str], batch_size: int = 16, max_length: int = 256) -> np.ndarray:
    all_embeddings = []

    for start in range(0, len(texts), batch_size):
        batch_texts = texts[start:start + batch_size]

        encoded = tokenizer(
            batch_texts,
            padding=True,
            truncation=True,
            max_length=max_length,
            return_tensors="pt",
        )

        encoded = {k: v.to(device) for k, v in encoded.items()}

        with torch.no_grad():
            output = model(**encoded)

        embeddings = mean_pooling(output, encoded["attention_mask"])
        embeddings = embeddings.detach().cpu().numpy()
        all_embeddings.append(embeddings)

    embeddings = np.vstack(all_embeddings)
    embeddings = l2_normalize(embeddings)

    return embeddings

# %%
sample_texts = [
    "British Shorthair is a calm and loyal cat with a dense coat.",
    "Maine Coon is a large gentle cat with a long coat.",
    "Sphynx is a hairless friendly cat.",
    "Сиамская кошка разговорчивая и умная.",
]

sample_embeddings = embed_texts(sample_texts, batch_size=4)

print("Sample embeddings shape:", sample_embeddings.shape)

similarity_matrix = sample_embeddings @ sample_embeddings.T

print("Similarity matrix:")
print(np.round(similarity_matrix, 3))
# Out:
# Sample embeddings shape: (4, 384)
# Similarity matrix:
# [[1.    0.657 0.533 0.654]
#  [0.657 1.    0.417 0.651]
#  [0.533 0.417 1.    0.488]
#  [0.654 0.651 0.488 1.   ]]

# %%
chunk_texts = [chunk["text"] for chunk in chunks]
chunk_ids = [chunk["chunk_id"] for chunk in chunks]

chunk_embeddings = embed_texts(
    chunk_texts,
    batch_size=16,
    max_length=256,
)

print("Chunks:", len(chunk_texts))
print("Chunk embeddings shape:", chunk_embeddings.shape)

assert chunk_embeddings.shape[0] == len(chunks)
# Out:
# Chunks: 67
# Chunk embeddings shape: (67, 384)

# %%
INDEX_DIR = Path("catapi_vector_index")
INDEX_DIR.mkdir(exist_ok=True)

EMBEDDINGS_PATH = INDEX_DIR / "catapi_chunk_embeddings.npy"
IDS_PATH = INDEX_DIR / "catapi_chunk_ids.json"

np.save(EMBEDDINGS_PATH, chunk_embeddings)

with IDS_PATH.open("w", encoding="utf-8") as f:
    json.dump(chunk_ids, f, ensure_ascii=False, indent=2)

print("Saved embeddings:", EMBEDDINGS_PATH)
print("Saved chunk ids:", IDS_PATH)
# Out:
# Saved embeddings: catapi_vector_index/catapi_chunk_embeddings.npy
# Saved chunk ids: catapi_vector_index/catapi_chunk_ids.json

# %%
def semantic_retrieve_v2(question: str, top_k: int = 5) -> Dict[str, Any]:
    query_embedding = embed_texts([question], batch_size=1, max_length=128)[0]

    scores = chunk_embeddings @ query_embedding
    top_indices = np.argsort(scores)[::-1][:top_k]

    results = []

    for rank, idx in enumerate(top_indices, start=1):
        results.append({
            "rank": rank,
            "score": float(scores[idx]),
            "chunk": chunks[int(idx)],
        })

    return {
        "strategy": "semantic_transformers_numpy",
        "detected_breed": None,
        "results": results,
        "warning": None,
    }

# %%
semantic_queries = [
    "British Shorthair round face dense coat",
    "large gentle calm cat",
    "hairless cat care",
    "vocal intelligent cat",
    "long hair grooming",
    "британская кошка круглая морда плотная шерсть",
    "мейн кун большой спокойный кот",
    "как ухаживать за сфинксом",
    "сиамская кошка разговорчивая",
    "персидская кошка длинная шерсть уход",
]

for q in semantic_queries:
    result = semantic_retrieve_v2(q, top_k=5)
    print_retrieval_result_v2(q, result)
# Out:
# ====================================================================================================
# QUESTION: British Shorthair round face dense coat
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.38961997628211975
# breed: British Longhair
# breed_id: bslo
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Longhair
# reference_image_id: 7isAO4Cav
# image_url: None
# text: Breed name: British Longhair Description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up. Temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social ...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.3296986222267151
# breed: British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
# image_url: None
# text: Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good com...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.2766651213169098
# breed: Scottish Fold
# breed_id: sfol
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/Scottish_Fold
# reference_image_id: o9t0LDcsa
# image_url: None
# text: Breed name: Scottish Fold Description: The Scottish Fold is a sweet, charming breed. She is an easy cat to live with and to care for. She is affectionate and is comfortable with all members of her family. Her tail should be handled gently. Folds are known for sleeping on their backs, and for sitting with their legs stretched out and their paws on their belly. This is called the "Buddha Position". Temperament: Affectionate, Intelligent, Loyal, Pla...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.27121198177337646
# breed: American Shorthair
# breed_id: asho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/American_Shorthair
# reference_image_id: JFPROfGtQ
# image_url: None
# text: Breed name: American Shorthair Description: The American Shorthair is known for its longevity, robust health, good looks, sweet personality, and amiability with children, dogs, and other pets. Temperament: Active, Curious, Easy Going, Playful, Calm Origin: United States Life span: 15 - 17 years Weight: 4 - 7 kg (8 - 15 lb) Grooming level: 1 Energy level: 3 Health issues score: 3 Child friendly score: 4 Dog friendly score: 5 Stranger friendly scor...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.25647658109664917
# breed: Snowshoe
# breed_id: snow
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Snowshoe_(cat)
# reference_image_id: MK-sYESvO
# image_url: None
# text: Breed name: Snowshoe Description: The Snowshoe is a vibrant, energetic, affectionate and intelligent cat. They love being around people which makes them ideal for families, and becomes unhappy when left alone for long periods of time. Usually attaching themselves to one person, they do whatever they can to get your attention. Temperament: Affectionate, Social, Intelligent, Sweet-tempered Origin: United States Life span: 14 - 19 years Weight: 3 - ...
# ====================================================================================================
# QUESTION: large gentle calm cat
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.38214242458343506
# breed: Norwegian Forest Cat
# breed_id: norw
# origin: Norway
# wikipedia_url: https://en.wikipedia.org/wiki/Norwegian_Forest_Cat
# reference_image_id: 06dgGmEOV
# image_url: None
# text: Breed name: Norwegian Forest Cat Description: The Norwegian Forest Cat is a sweet, loving cat. She appreciates praise and loves to interact with her parent. She makes a loving companion and bonds with her parents once she accepts them for her own. She is still a hunter at heart. She loves to chase toys as if they are real. She is territorial and patrols several times each day to make certain that all is fine. Temperament: Sweet, Active, Intellige...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.34797167778015137
# breed: Abyssinian
# breed_id: abys
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Abyssinian_(cat)
# reference_image_id: 0XYvRd7oD
# image_url: None
# text: Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperament: Active, Energetic, Independent, Intelligent, Gentle Origin: Egypt Life span: 14 - 15 years Weight: 3 - 5 kg (7  -  10 lb) Grooming level: 1 Energy level: 5 Health issues score: 2 Child friendly score: 3 Dog friendly score: 4 Stranger friendly score: 5 Intelligence sc...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.3429928719997406
# breed: York Chocolate
# breed_id: ycho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/York_Chocolate
# reference_image_id: 0SxW2SQ_S
# image_url: None
# text: Breed name: York Chocolate Description: York Chocolate cats are known to be true lap cats with a sweet temperament. They love to be cuddled and petted. Their curious nature makes them follow you all the time and participate in almost everything you do, even if it's related to water: unlike many other cats, York Chocolates love it. Temperament: Playful, Social, Intelligent, Curious, Friendly Origin: United States Life span: 13 - 15 years Weight: 5...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.324890673160553
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# image_url: None
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.32052794098854065
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# image_url: None
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# ====================================================================================================
# QUESTION: hairless cat care
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.46043673157691956
# breed: Cymric
# breed_id: cymr
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Cymric_(cat)
# reference_image_id: 3dbtapCWM
# image_url: None
# text: Breed name: Cymric Description: The Cymric is a placid, sweet cat. They do not get too upset about anything that happens in their world. They are loving companions and adore people. They are smart and dexterous, capable of using his paws to get into cabinets or to open doors. Temperament: Gentle, Loyal, Intelligent, Playful Origin: Canada Life span: 8 - 14 years Weight: 4 - 6 kg (8 - 13 lb) Grooming level: 3 Energy level: 5 Health issues score: 3...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.4433242082595825
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# image_url: None
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.42204946279525757
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# image_url: None
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.4078734517097473
# breed: Bengal
# breed_id: beng
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bengal_(cat)
# reference_image_id: O3btzLlsO
# image_url: None
# text: Breed name: Bengal Description: Bengals are a lot of fun to live with, but they're definitely not the cat for everyone, or for first-time cat owners. Extremely intelligent, curious and active, they demand a lot of interaction and woe betide the owner who doesn't provide it. Temperament: Alert, Agile, Energetic, Demanding, Intelligent Origin: United States Life span: 12 - 15 years Weight: 3 - 7 kg (6 - 12 lb) Grooming level: 1 Energy level: 5 Heal...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.3911411762237549
# breed: Siamese
# breed_id: siam
# origin: Thailand
# wikipedia_url: https://en.wikipedia.org/wiki/Siamese_(cat)
# reference_image_id: ai6Jps4sx
# image_url: None
# text: Breed name: Siamese Description: While Siamese cats are extremely fond of their people, they will follow you around and supervise your every move, being talkative and opinionated. They are a demanding and social cat, that do not like being left alone for long periods. Temperament: Active, Agile, Clever, Sociable, Loving, Energetic Origin: Thailand Life span: 12 - 15 years Weight: 4 - 7 kg (8 - 15 lb) Grooming level: 1 Energy level: 5 Health issue...
# ====================================================================================================
# QUESTION: vocal intelligent cat
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.4264158606529236
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# image_url: None
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.39449402689933777
# breed: Donskoy
# breed_id: dons
# origin: Russia
# wikipedia_url: https://en.wikipedia.org/wiki/Donskoy_(cat)
# reference_image_id: 3KG57GfMW
# image_url: None
# text: Breed name: Donskoy Description: Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer the less hair they have. Temperament: Playful, affectionate, loyal, social Origin: Russia Life span: 12 - 15 years Weig...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.38930076360702515
# breed: York Chocolate
# breed_id: ycho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/York_Chocolate
# reference_image_id: 0SxW2SQ_S
# image_url: None
# text: Breed name: York Chocolate Description: York Chocolate cats are known to be true lap cats with a sweet temperament. They love to be cuddled and petted. Their curious nature makes them follow you all the time and participate in almost everything you do, even if it's related to water: unlike many other cats, York Chocolates love it. Temperament: Playful, Social, Intelligent, Curious, Friendly Origin: United States Life span: 13 - 15 years Weight: 5...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.37751662731170654
# breed: Korat
# breed_id: kora
# origin: Thailand
# wikipedia_url: https://en.wikipedia.org/wiki/Korat
# reference_image_id: DbwiefiaY
# image_url: None
# text: Breed name: Korat Description: The Korat is a natural breed, and one of the oldest stable cat breeds. They are highly intelligent and confident cats that can be fearless, although they are startled by loud sounds and sudden movements. Korats form strong bonds with their people and like to cuddle and stay nearby. Temperament: Active, Loyal, highly intelligent, Expressive, Trainable Origin: Thailand Life span: 10 - 15 years Weight: 3 - 5 kg (7 - 11...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.3773301839828491
# breed: Tonkinese
# breed_id: tonk
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Tonkinese_(cat)
# reference_image_id: KBroiVNCM
# image_url: None
# text: Breed name: Tonkinese Description: Intelligent and generous with their affection, a Tonkinese will supervise all activities with curiosity. Loving, social, active, playful, yet content to be a lap cat Temperament: Curious, Intelligent, Social, Lively, Outgoing, Playful, Affectionate Origin: Canada Life span: 14 - 16 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 1 Energy level: 5 Health issues score: 1 Child friendly score: 4 Dog friendly sco...
# ====================================================================================================
# QUESTION: long hair grooming
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.31864920258522034
# breed: American Shorthair
# breed_id: asho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/American_Shorthair
# reference_image_id: JFPROfGtQ
# image_url: None
# text: Breed name: American Shorthair Description: The American Shorthair is known for its longevity, robust health, good looks, sweet personality, and amiability with children, dogs, and other pets. Temperament: Active, Curious, Easy Going, Playful, Calm Origin: United States Life span: 15 - 17 years Weight: 4 - 7 kg (8 - 15 lb) Grooming level: 1 Energy level: 3 Health issues score: 3 Child friendly score: 4 Dog friendly score: 5 Stranger friendly scor...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.2568952143192291
# breed: Colorpoint Shorthair
# breed_id: csho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Colorpoint_Shorthair
# reference_image_id: oSpqGyUDS
# image_url: None
# text: Breed name: Colorpoint Shorthair Description: Colorpoint Shorthairs are an affectionate breed, devoted and loyal to their people. Sensitive to their owner’s moods, Colorpoints are more than happy to sit at your side or on your lap and purr words of encouragement on a bad day. They will constantly seek out your lap whenever it is open and in the moments when your lap is preoccupied they will stretch out in sunny spots on the ground. Temperament: A...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.2525298297405243
# breed: Munchkin
# breed_id: munc
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Munchkin_(cat)
# reference_image_id: j5cVSqLer
# image_url: None
# text: Breed name: Munchkin Description: The Munchkin is an outgoing cat who enjoys being handled. She has lots of energy and is faster and more agile than she looks. The shortness of their legs does not seem to interfere with their running and leaping abilities. Temperament: Agile, Easy Going, Intelligent, Playful Origin: United States Life span: 10 - 15 years Weight: 2 - 4 kg (5 - 9 lb) Grooming level: 2 Energy level: 4 Health issues score: 3 Child fr...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.22855256497859955
# breed: British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
# image_url: None
# text: Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good com...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.22832091152668
# breed: Pixie-bob
# breed_id: pixi
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Pixiebob
# reference_image_id: z7fJRNeN6
# image_url: None
# text: Breed name: Pixie-bob Description: Companionable and affectionate, the Pixie-bob wants to be an integral part of the family. The Pixie-Bob’s ability to bond with their humans along with their patient personas make them excellent companions for children. Temperament: Affectionate, Social, Intelligent, Loyal Origin: United States Life span: 13 - 16 years Weight: 4 - 8 kg (8 - 17 lb) Grooming level: 1 Energy level: 4 Health issues score: 2 Child fri...
# ====================================================================================================
# QUESTION: британская кошка круглая морда плотная шерсть
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.39232808351516724
# breed: Abyssinian
# breed_id: abys
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Abyssinian_(cat)
# reference_image_id: 0XYvRd7oD
# image_url: None
# text: Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperament: Active, Energetic, Independent, Intelligent, Gentle Origin: Egypt Life span: 14 - 15 years Weight: 3 - 5 kg (7  -  10 lb) Grooming level: 1 Energy level: 5 Health issues score: 2 Child friendly score: 3 Dog friendly score: 4 Stranger friendly score: 5 Intelligence sc...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.37981298565864563
# breed: American Bobtail
# breed_id: abob
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/American_Bobtail
# reference_image_id: hBXicehMA
# image_url: None
# text: Breed name: American Bobtail Description: American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion. Temperament: Intelligent, Interactive, Lively, Playful, Sensitive Origin: United States Life span: 11 - 15 years Weight: 3 - 7 kg (7 - 16 lb) Grooming level: 1 Energy level: 3 Health issues score: 1 Child friendly ...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.36649882793426514
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# image_url: None
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.35215795040130615
# breed: British Longhair
# breed_id: bslo
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Longhair
# reference_image_id: 7isAO4Cav
# image_url: None
# text: Breed name: British Longhair Description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up. Temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social ...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.3496789336204529
# breed: York Chocolate
# breed_id: ycho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/York_Chocolate
# reference_image_id: 0SxW2SQ_S
# image_url: None
# text: Breed name: York Chocolate Description: York Chocolate cats are known to be true lap cats with a sweet temperament. They love to be cuddled and petted. Their curious nature makes them follow you all the time and participate in almost everything you do, even if it's related to water: unlike many other cats, York Chocolates love it. Temperament: Playful, Social, Intelligent, Curious, Friendly Origin: United States Life span: 13 - 15 years Weight: 5...
# ====================================================================================================
# QUESTION: мейн кун большой спокойный кот
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.43631237745285034
# breed: Abyssinian
# breed_id: abys
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Abyssinian_(cat)
# reference_image_id: 0XYvRd7oD
# image_url: None
# text: Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperament: Active, Energetic, Independent, Intelligent, Gentle Origin: Egypt Life span: 14 - 15 years Weight: 3 - 5 kg (7  -  10 lb) Grooming level: 1 Energy level: 5 Health issues score: 2 Child friendly score: 3 Dog friendly score: 4 Stranger friendly score: 5 Intelligence sc...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.4119347929954529
# breed: Norwegian Forest Cat
# breed_id: norw
# origin: Norway
# wikipedia_url: https://en.wikipedia.org/wiki/Norwegian_Forest_Cat
# reference_image_id: 06dgGmEOV
# image_url: None
# text: Breed name: Norwegian Forest Cat Description: The Norwegian Forest Cat is a sweet, loving cat. She appreciates praise and loves to interact with her parent. She makes a loving companion and bonds with her parents once she accepts them for her own. She is still a hunter at heart. She loves to chase toys as if they are real. She is territorial and patrols several times each day to make certain that all is fine. Temperament: Sweet, Active, Intellige...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.41020241379737854
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# image_url: None
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.38681864738464355
# breed: York Chocolate
# breed_id: ycho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/York_Chocolate
# reference_image_id: 0SxW2SQ_S
# image_url: None
# text: Breed name: York Chocolate Description: York Chocolate cats are known to be true lap cats with a sweet temperament. They love to be cuddled and petted. Their curious nature makes them follow you all the time and participate in almost everything you do, even if it's related to water: unlike many other cats, York Chocolates love it. Temperament: Playful, Social, Intelligent, Curious, Friendly Origin: United States Life span: 13 - 15 years Weight: 5...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.38403064012527466
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# image_url: None
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# ====================================================================================================
# QUESTION: как ухаживать за сфинксом
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.20947232842445374
# breed: Dragon Li
# breed_id: lihu
# origin: China
# wikipedia_url: https://en.wikipedia.org/wiki/Dragon_Li
# reference_image_id: BQMSld0A0
# image_url: None
# text: Breed name: Dragon Li Description: The Dragon Li is loyal, but not particularly affectionate. They are known to be very intelligent, and their natural breed status means that they're very active. She is is gentle with people, and has a reputation as a talented hunter of rats and other vermin. Temperament: Intelligent, Friendly, Gentle, Loving, Loyal Origin: China Life span: 12 - 15 years Weight: 4 - 6 kg (9 - 12 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.1759222447872162
# breed: American Bobtail
# breed_id: abob
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/American_Bobtail
# reference_image_id: hBXicehMA
# image_url: None
# text: Breed name: American Bobtail Description: American Bobtails are loving and incredibly intelligent cats possessing a distinctive wild appearance. They are extremely interactive cats that bond with their human family with great devotion. Temperament: Intelligent, Interactive, Lively, Playful, Sensitive Origin: United States Life span: 11 - 15 years Weight: 3 - 7 kg (7 - 16 lb) Grooming level: 1 Energy level: 3 Health issues score: 1 Child friendly ...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.1700890064239502
# breed: Cornish Rex
# breed_id: crex
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/Cornish_Rex
# reference_image_id: unX21IBVB
# image_url: None
# text: Breed name: Cornish Rex Description: This is a confident cat who loves people and will follow them around, waiting for any opportunity to sit in a lap or give a kiss. He enjoys being handled, making it easy to take him to the veterinarian or train him for therapy work. The Cornish Rex stay in kitten mode most of their lives and well into their senior years.  Temperament: Affectionate, Intelligent, Active, Curious, Playful Origin: United Kingdom L...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.16963711380958557
# breed: Munchkin
# breed_id: munc
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Munchkin_(cat)
# reference_image_id: j5cVSqLer
# image_url: None
# text: Breed name: Munchkin Description: The Munchkin is an outgoing cat who enjoys being handled. She has lots of energy and is faster and more agile than she looks. The shortness of their legs does not seem to interfere with their running and leaping abilities. Temperament: Agile, Easy Going, Intelligent, Playful Origin: United States Life span: 10 - 15 years Weight: 2 - 4 kg (5 - 9 lb) Grooming level: 2 Energy level: 4 Health issues score: 3 Child fr...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.16781306266784668
# breed: Abyssinian
# breed_id: abys
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Abyssinian_(cat)
# reference_image_id: 0XYvRd7oD
# image_url: None
# text: Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperament: Active, Energetic, Independent, Intelligent, Gentle Origin: Egypt Life span: 14 - 15 years Weight: 3 - 5 kg (7  -  10 lb) Grooming level: 1 Energy level: 5 Health issues score: 2 Child friendly score: 3 Dog friendly score: 4 Stranger friendly score: 5 Intelligence sc...
# ====================================================================================================
# QUESTION: сиамская кошка разговорчивая
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.4412072002887726
# breed: Abyssinian
# breed_id: abys
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Abyssinian_(cat)
# reference_image_id: 0XYvRd7oD
# image_url: None
# text: Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperament: Active, Energetic, Independent, Intelligent, Gentle Origin: Egypt Life span: 14 - 15 years Weight: 3 - 5 kg (7  -  10 lb) Grooming level: 1 Energy level: 5 Health issues score: 2 Child friendly score: 3 Dog friendly score: 4 Stranger friendly score: 5 Intelligence sc...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.429645836353302
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# image_url: None
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.4295644164085388
# breed: Norwegian Forest Cat
# breed_id: norw
# origin: Norway
# wikipedia_url: https://en.wikipedia.org/wiki/Norwegian_Forest_Cat
# reference_image_id: 06dgGmEOV
# image_url: None
# text: Breed name: Norwegian Forest Cat Description: The Norwegian Forest Cat is a sweet, loving cat. She appreciates praise and loves to interact with her parent. She makes a loving companion and bonds with her parents once she accepts them for her own. She is still a hunter at heart. She loves to chase toys as if they are real. She is territorial and patrols several times each day to make certain that all is fine. Temperament: Sweet, Active, Intellige...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.4156627357006073
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# image_url: None
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.4155399203300476
# breed: Donskoy
# breed_id: dons
# origin: Russia
# wikipedia_url: https://en.wikipedia.org/wiki/Donskoy_(cat)
# reference_image_id: 3KG57GfMW
# image_url: None
# text: Breed name: Donskoy Description: Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer the less hair they have. Temperament: Playful, affectionate, loyal, social Origin: Russia Life span: 12 - 15 years Weig...
# ====================================================================================================
# QUESTION: персидская кошка длинная шерсть уход
# STRATEGY: semantic_transformers_numpy
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.4598691165447235
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# image_url: None
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.4359578490257263
# breed: Abyssinian
# breed_id: abys
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Abyssinian_(cat)
# reference_image_id: 0XYvRd7oD
# image_url: None
# text: Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperament: Active, Energetic, Independent, Intelligent, Gentle Origin: Egypt Life span: 14 - 15 years Weight: 3 - 5 kg (7  -  10 lb) Grooming level: 1 Energy level: 5 Health issues score: 2 Child friendly score: 3 Dog friendly score: 4 Stranger friendly score: 5 Intelligence sc...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.3896147608757019
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# image_url: None
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.3636137843132019
# breed: Norwegian Forest Cat
# breed_id: norw
# origin: Norway
# wikipedia_url: https://en.wikipedia.org/wiki/Norwegian_Forest_Cat
# reference_image_id: 06dgGmEOV
# image_url: None
# text: Breed name: Norwegian Forest Cat Description: The Norwegian Forest Cat is a sweet, loving cat. She appreciates praise and loves to interact with her parent. She makes a loving companion and bonds with her parents once she accepts them for her own. She is still a hunter at heart. She loves to chase toys as if they are real. She is territorial and patrols several times each day to make certain that all is fine. Temperament: Sweet, Active, Intellige...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.359931617975235
# breed: Siberian
# breed_id: sibe
# origin: Russia
# wikipedia_url: https://en.wikipedia.org/wiki/Siberian_(cat)
# reference_image_id: 3bkZAjRh1
# image_url: None
# text: Breed name: Siberian Description: The Siberians dog like temperament and affection makes the ideal lap cat and will live quite happily indoors. Very agile and powerful, the Siberian cat can easily leap and reach high places, including the tops of refrigerators and even doors.  Temperament: Curious, Intelligent, Loyal, Sweet, Agile, Playful, Affectionate Origin: Russia Life span: 12 - 15 years Weight: 4 - 7 kg (8 - 16 lb) Grooming level: 2 Energy ...

# %%
compare_queries = [
    "Чем британские котики отличаются от обычных?",
    "Какая кошка большая, спокойная и ласковая?",
    "Какая кошка разговорчивая и умная?",
    "Как ухаживать за сфинксом?",
    "hairless cat care",
    "long hair grooming",
    "какая кошка умеет чинить ноутбук?",
]

for q in compare_queries:
    print("=" * 120)
    print("QUESTION:", q)

    print("\nHYBRID V2")
    hybrid_result = hybrid_retrieve_v2(q, top_k=3)

    if hybrid_result.get("warning"):
        print("WARNING:", hybrid_result["warning"])

    for item in hybrid_result.get("results", []):
        print(
            item["rank"],
            item["score"],
            item["chunk"].get("breed_name"),
        )

    print("\nSEMANTIC V2")
    semantic_result = semantic_retrieve_v2(q, top_k=3)

    if semantic_result.get("warning"):
        print("WARNING:", semantic_result["warning"])

    for item in semantic_result.get("results", []):
        print(
            item["rank"],
            round(item["score"], 4),
            item["chunk"].get("breed_name"),
        )

    print()
# Out:
# ========================================================================================================================
# QUESTION: Чем британские котики отличаются от обычных?
#
# HYBRID V2
# 1 None British Shorthair
#
# SEMANTIC V2
# 1 0.4592 British Longhair
# 2 0.4533 Abyssinian
# 3 0.4505 York Chocolate
#
# ========================================================================================================================
# QUESTION: Какая кошка большая, спокойная и ласковая?
#
# HYBRID V2
# 1 20 British Shorthair
# 2 14 Ragamuffin
# 3 14 Ragdoll
#
# SEMANTIC V2
# 1 0.45 Abyssinian
# 2 0.4322 Norwegian Forest Cat
# 3 0.4297 York Chocolate
#
# ========================================================================================================================
# QUESTION: Какая кошка разговорчивая и умная?
#
# HYBRID V2
# 1 10 Balinese
# 2 10 Bengal
# 3 10 Bombay
#
# SEMANTIC V2
# 1 0.4497 York Chocolate
# 2 0.4488 Donskoy
# 3 0.4352 Bambino
#
# ========================================================================================================================
# QUESTION: Как ухаживать за сфинксом?
#
# HYBRID V2
# 1 None Sphynx
#
# SEMANTIC V2
# 1 0.1753 Dragon Li
# 2 0.1471 American Bobtail
# 3 0.1467 Munchkin
#
# ========================================================================================================================
# QUESTION: hairless cat care
#
# HYBRID V2
# 1 10 Donskoy
# 2 10 Sphynx
# 3 9 Bambino
#
# SEMANTIC V2
# 1 0.4604 Cymric
# 2 0.4433 Bambino
# 3 0.422 Persian
#
# ========================================================================================================================
# QUESTION: long hair grooming
#
# HYBRID V2
# 1 5 British Longhair
# 2 5 Chantilly-Tiffany
# 3 5 Himalayan
#
# SEMANTIC V2
# 1 0.3186 American Shorthair
# 2 0.2569 Colorpoint Shorthair
# 3 0.2525 Munchkin
#
# ========================================================================================================================
# QUESTION: какая кошка умеет чинить ноутбук?
#
# HYBRID V2
# WARNING: No relevant CatAPI context found with current retrieval rules.
#
# SEMANTIC V2
# 1 0.3214 Bambino
# 2 0.3051 York Chocolate
# 3 0.3019 Norwegian Forest Cat

# %%
def full_retrieve(question: str, top_k: int = 5) -> Dict[str, Any]:
    """
    Full retrieval strategy:

    1. Alias exact breed detection.
    2. Structured retrieval.
    3. Semantic retrieval.
    4. Merge and rerank.
    """

    detected_breed = detect_breed_alias(question)

    # 1. Если явно названа порода — это самый надёжный сигнал
    if detected_breed:
        chunk = chunk_by_breed.get(detected_breed)
        if chunk:
            return {
                "strategy": "alias_exact_breed",
                "detected_breed": detected_breed,
                "results": [
                    {
                        "rank": 1,
                        "score": 1.0,
                        "score_type": "alias",
                        "chunk": chunk,
                    }
                ],
                "warning": None,
            }

    # 2. Structured results
    structured_result = hybrid_retrieve_v2(question, top_k=top_k)
    structured_items = structured_result.get("results", [])

    # 3. Semantic results
    semantic_result = semantic_retrieve_v2(question, top_k=top_k)
    semantic_items = semantic_result.get("results", [])

    merged = {}

    # Structured score: грубо нормируем
    for item in structured_items:
        chunk = item["chunk"]
        chunk_id = chunk["chunk_id"]
        raw_score = item["score"] or 0

        merged.setdefault(chunk_id, {
            "chunk": chunk,
            "structured_score": 0.0,
            "semantic_score": 0.0,
        })

        merged[chunk_id]["structured_score"] = min(raw_score / 20, 1.0)

    # Semantic score: cosine similarity уже примерно [-1, 1]
    for item in semantic_items:
        chunk = item["chunk"]
        chunk_id = chunk["chunk_id"]
        raw_score = item["score"] or 0.0

        merged.setdefault(chunk_id, {
            "chunk": chunk,
            "structured_score": 0.0,
            "semantic_score": 0.0,
        })

        merged[chunk_id]["semantic_score"] = max(raw_score, 0.0)

    ranked = []

    for chunk_id, item in merged.items():
        final_score = (
            0.45 * item["structured_score"]
            + 0.55 * item["semantic_score"]
        )

        ranked.append({
            "chunk_id": chunk_id,
            "chunk": item["chunk"],
            "structured_score": item["structured_score"],
            "semantic_score": item["semantic_score"],
            "score": final_score,
        })

    ranked = sorted(ranked, key=lambda x: x["score"], reverse=True)

    results = []

    for rank, item in enumerate(ranked[:top_k], start=1):
        results.append({
            "rank": rank,
            "score": item["score"],
            "score_type": "hybrid_structured_semantic",
            "structured_score": item["structured_score"],
            "semantic_score": item["semantic_score"],
            "chunk": item["chunk"],
        })

    if not results or results[0]["score"] < 0.15:
        return {
            "strategy": "full_retrieval_no_confident_match",
            "detected_breed": detected_breed,
            "results": [],
            "warning": "No confident CatAPI context found.",
        }

    return {
        "strategy": "full_hybrid_retrieval",
        "detected_breed": detected_breed,
        "results": results,
        "warning": None,
    }

# %%
def print_full_retrieval_result(question: str, result: Dict[str, Any]):
    print("=" * 100)
    print("QUESTION:", question)
    print("STRATEGY:", result.get("strategy"))
    print("DETECTED BREED:", result.get("detected_breed"))

    if result.get("warning"):
        print("WARNING:", result["warning"])

    if not result.get("results"):
        print("No retrieved context.")
        return

    for item in result["results"]:
        chunk = item["chunk"]
        metadata = chunk.get("metadata", {}) or {}

        print("-" * 80)
        print("rank:", item["rank"])
        print("score:", round(item["score"], 4) if item["score"] is not None else None)
        print("score_type:", item.get("score_type"))
        print("structured_score:", round(item.get("structured_score", 0), 4))
        print("semantic_score:", round(item.get("semantic_score", 0), 4))
        print("breed:", chunk.get("breed_name"))
        print("breed_id:", chunk.get("breed_id"))
        print("origin:", metadata.get("origin"))
        print("wikipedia_url:", metadata.get("wikipedia_url"))
        print("reference_image_id:", metadata.get("reference_image_id"))
        print("text:", preview_text(chunk.get("text", ""), 450))

# %%
full_queries = [
    "Чем британские котики отличаются от обычных?",
    "Какая кошка большая, спокойная и ласковая?",
    "Какая кошка разговорчивая и умная?",
    "Как ухаживать за сфинксом?",
    "hairless cat care",
    "long hair grooming",
    "персидская кошка длинная шерсть уход",
    "какая кошка умеет чинить ноутбук?",
]

for q in full_queries:
    result = full_retrieve(q, top_k=5)
    print_full_retrieval_result(q, result)
# Out:
# ====================================================================================================
# QUESTION: Чем британские котики отличаются от обычных?
# STRATEGY: alias_exact_breed
# DETECTED BREED: British Shorthair
# --------------------------------------------------------------------------------
# rank: 1
# score: 1.0
# score_type: alias
# structured_score: 0
# semantic_score: 0
# breed: British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
# text: Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good com...
# ====================================================================================================
# QUESTION: Какая кошка большая, спокойная и ласковая?
# STRATEGY: full_hybrid_retrieval
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.45
# score_type: hybrid_structured_semantic
# structured_score: 1.0
# semantic_score: 0.0
# breed: British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
# text: Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good com...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.315
# score_type: hybrid_structured_semantic
# structured_score: 0.7
# semantic_score: 0.0
# breed: Ragamuffin
# breed_id: raga
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Ragamuffin_cat
# reference_image_id: SMuZx-bFM
# text: Breed name: Ragamuffin Description: The Ragamuffin is calm, even tempered and gets along well with all family members. Changes in routine generally do not upset her. She is an ideal companion for those in apartments, and with children due to her patient nature. Temperament: Affectionate, Friendly, Gentle, Calm Origin: United States Life span: 12 - 16 years Weight: 4 - 9 kg (8 - 20 lb) Grooming level: 3 Energy level: 3 Health issues score: 3 Child...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.315
# score_type: hybrid_structured_semantic
# structured_score: 0.7
# semantic_score: 0.0
# breed: Ragdoll
# breed_id: ragd
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Ragdoll
# reference_image_id: oGefY4YoG
# text: Breed name: Ragdoll Description: Ragdolls love their people, greeting them at the door, following them around the house, and leaping into a lap or snuggling in bed whenever given the chance. They are the epitome of a lap cat, enjoy being carried and collapsing into the arms of anyone who holds them. Temperament: Affectionate, Friendly, Gentle, Quiet, Easygoing Origin: United States Life span: 12 - 17 years Weight: 5 - 9 kg (12 - 20 lb) Grooming l...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.315
# score_type: hybrid_structured_semantic
# structured_score: 0.7
# semantic_score: 0.0
# breed: Selkirk Rex
# breed_id: srex
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Selkirk_Rex
# reference_image_id: II9dOZmrw
# text: Breed name: Selkirk Rex Description: The Selkirk Rex is an incredibly patient, loving, and tolerant breed. The Selkirk also has a silly side and is sometimes described as clownish. She loves being a lap cat and will be happy to chat with you in a quiet voice if you talk to her.  Temperament: Active, Affectionate, Dependent, Gentle, Patient, Playful, Quiet, Social Origin: United States Life span: 14 - 15 years Weight: 3 - 7 kg (6 - 16 lb) Grooming...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.2475
# score_type: hybrid_structured_semantic
# structured_score: 0.55
# semantic_score: 0.0
# breed: British Longhair
# breed_id: bslo
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Longhair
# reference_image_id: 7isAO4Cav
# text: Breed name: British Longhair Description: The British Longhair is a very laid-back relaxed cat, often perceived to be very independent although they will enjoy the company of an equally relaxed and likeminded cat. They are an affectionate breed, but very much on their own terms and tend to prefer to choose to come and sit with their owners rather than being picked up. Temperament: Affectionate, Easy Going, Independent, Intelligent, Loyal, Social ...
# ====================================================================================================
# QUESTION: Какая кошка разговорчивая и умная?
# STRATEGY: full_hybrid_retrieval
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.2474
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.4497
# breed: York Chocolate
# breed_id: ycho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/York_Chocolate
# reference_image_id: 0SxW2SQ_S
# text: Breed name: York Chocolate Description: York Chocolate cats are known to be true lap cats with a sweet temperament. They love to be cuddled and petted. Their curious nature makes them follow you all the time and participate in almost everything you do, even if it's related to water: unlike many other cats, York Chocolates love it. Temperament: Playful, Social, Intelligent, Curious, Friendly Origin: United States Life span: 13 - 15 years Weight: 5...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.2469
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.4488
# breed: Donskoy
# breed_id: dons
# origin: Russia
# wikipedia_url: https://en.wikipedia.org/wiki/Donskoy_(cat)
# reference_image_id: 3KG57GfMW
# text: Breed name: Donskoy Description: Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer the less hair they have. Temperament: Playful, affectionate, loyal, social Origin: Russia Life span: 12 - 15 years Weig...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.2393
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.4352
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.2391
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.4347
# breed: Chausie
# breed_id: chau
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Chausie
# reference_image_id: vJ3lEYgXr
# text: Breed name: Chausie Description: For those owners who desire a feline capable of evoking the great outdoors, the strikingly beautiful Chausie retains a bit of the wild in its appearance but has the house manners of our friendly, familiar moggies. Very playful, this cat needs a large amount of space to be able to fully embrace its hunting instincts. Temperament: Affectionate, Intelligent, Playful, Social Origin: Egypt Life span: 12 - 14 years Weig...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.2339
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.4253
# breed: Norwegian Forest Cat
# breed_id: norw
# origin: Norway
# wikipedia_url: https://en.wikipedia.org/wiki/Norwegian_Forest_Cat
# reference_image_id: 06dgGmEOV
# text: Breed name: Norwegian Forest Cat Description: The Norwegian Forest Cat is a sweet, loving cat. She appreciates praise and loves to interact with her parent. She makes a loving companion and bonds with her parents once she accepts them for her own. She is still a hunter at heart. She loves to chase toys as if they are real. She is territorial and patrols several times each day to make certain that all is fine. Temperament: Sweet, Active, Intellige...
# ====================================================================================================
# QUESTION: Как ухаживать за сфинксом?
# STRATEGY: alias_exact_breed
# DETECTED BREED: Sphynx
# --------------------------------------------------------------------------------
# rank: 1
# score: 1.0
# score_type: alias
# structured_score: 0
# semantic_score: 0
# breed: Sphynx
# breed_id: sphy
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Sphynx_(cat)
# reference_image_id: BDb8ZXb1v
# text: Breed name: Sphynx Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression. Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle Origin: Canada Life span: 12 - 14 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 2 Energy lev...
# ====================================================================================================
# QUESTION: hairless cat care
# STRATEGY: full_hybrid_retrieval
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.4463
# score_type: hybrid_structured_semantic
# structured_score: 0.45
# semantic_score: 0.4433
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.2532
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.4604
# breed: Cymric
# breed_id: cymr
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Cymric_(cat)
# reference_image_id: 3dbtapCWM
# text: Breed name: Cymric Description: The Cymric is a placid, sweet cat. They do not get too upset about anything that happens in their world. They are loving companions and adore people. They are smart and dexterous, capable of using his paws to get into cabinets or to open doors. Temperament: Gentle, Loyal, Intelligent, Playful Origin: Canada Life span: 8 - 14 years Weight: 4 - 6 kg (8 - 13 lb) Grooming level: 3 Energy level: 5 Health issues score: 3...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.2321
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.422
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.225
# score_type: hybrid_structured_semantic
# structured_score: 0.5
# semantic_score: 0.0
# breed: Donskoy
# breed_id: dons
# origin: Russia
# wikipedia_url: https://en.wikipedia.org/wiki/Donskoy_(cat)
# reference_image_id: 3KG57GfMW
# text: Breed name: Donskoy Description: Donskoy are affectionate, intelligent, and easy-going. They demand lots of attention and interaction. The Donskoy also gets along well with other pets. It is now thought the same gene that causes degrees of hairlessness in the Donskoy also causes alterations in cat personality, making them calmer the less hair they have. Temperament: Playful, affectionate, loyal, social Origin: Russia Life span: 12 - 15 years Weig...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.225
# score_type: hybrid_structured_semantic
# structured_score: 0.5
# semantic_score: 0.0
# breed: Sphynx
# breed_id: sphy
# origin: Canada
# wikipedia_url: https://en.wikipedia.org/wiki/Sphynx_(cat)
# reference_image_id: BDb8ZXb1v
# text: Breed name: Sphynx Description: The Sphynx is an intelligent, inquisitive, extremely friendly people-oriented breed. Sphynx commonly greet their owners  at the front door, with obvious excitement and happiness. She has an unexpected sense of humor that is often at odds with her dour expression. Temperament: Loyal, Inquisitive, Friendly, Quiet, Gentle Origin: Canada Life span: 12 - 14 years Weight: 3 - 5 kg (6 - 12 lb) Grooming level: 2 Energy lev...
# ====================================================================================================
# QUESTION: long hair grooming
# STRATEGY: full_hybrid_retrieval
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.1753
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.3186
# breed: American Shorthair
# breed_id: asho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/American_Shorthair
# reference_image_id: JFPROfGtQ
# text: Breed name: American Shorthair Description: The American Shorthair is known for its longevity, robust health, good looks, sweet personality, and amiability with children, dogs, and other pets. Temperament: Active, Curious, Easy Going, Playful, Calm Origin: United States Life span: 15 - 17 years Weight: 4 - 7 kg (8 - 15 lb) Grooming level: 1 Energy level: 3 Health issues score: 3 Child friendly score: 4 Dog friendly score: 5 Stranger friendly scor...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.1413
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.2569
# breed: Colorpoint Shorthair
# breed_id: csho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Colorpoint_Shorthair
# reference_image_id: oSpqGyUDS
# text: Breed name: Colorpoint Shorthair Description: Colorpoint Shorthairs are an affectionate breed, devoted and loyal to their people. Sensitive to their owner’s moods, Colorpoints are more than happy to sit at your side or on your lap and purr words of encouragement on a bad day. They will constantly seek out your lap whenever it is open and in the moments when your lap is preoccupied they will stretch out in sunny spots on the ground. Temperament: A...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.1389
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.2525
# breed: Munchkin
# breed_id: munc
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Munchkin_(cat)
# reference_image_id: j5cVSqLer
# text: Breed name: Munchkin Description: The Munchkin is an outgoing cat who enjoys being handled. She has lots of energy and is faster and more agile than she looks. The shortness of their legs does not seem to interfere with their running and leaping abilities. Temperament: Agile, Easy Going, Intelligent, Playful Origin: United States Life span: 10 - 15 years Weight: 2 - 4 kg (5 - 9 lb) Grooming level: 2 Energy level: 4 Health issues score: 3 Child fr...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.1257
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.2286
# breed: British Shorthair
# breed_id: bsho
# origin: United Kingdom
# wikipedia_url: https://en.wikipedia.org/wiki/British_Shorthair
# reference_image_id: s4wQfYoEk
# text: Breed name: British Shorthair Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good com...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.1256
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.2283
# breed: Pixie-bob
# breed_id: pixi
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Pixiebob
# reference_image_id: z7fJRNeN6
# text: Breed name: Pixie-bob Description: Companionable and affectionate, the Pixie-bob wants to be an integral part of the family. The Pixie-Bob’s ability to bond with their humans along with their patient personas make them excellent companions for children. Temperament: Affectionate, Social, Intelligent, Loyal Origin: United States Life span: 13 - 16 years Weight: 4 - 8 kg (8 - 17 lb) Grooming level: 1 Energy level: 4 Health issues score: 2 Child fri...
# ====================================================================================================
# QUESTION: персидская кошка длинная шерсть уход
# STRATEGY: alias_exact_breed
# DETECTED BREED: Persian
# --------------------------------------------------------------------------------
# rank: 1
# score: 1.0
# score_type: alias
# structured_score: 0
# semantic_score: 0
# breed: Persian
# breed_id: pers
# origin: Iran (Persia)
# wikipedia_url: https://en.wikipedia.org/wiki/Persian_(cat)
# reference_image_id: -Zfz5z2jK
# text: Breed name: Persian Description: Persians are sweet, gentle cats that can be playful or quiet and laid-back. Great with families and children, they absolutely love to lounge around the house. While they don’t mind a full house or active kids, they’ll usually hide when they need some alone time. Temperament: Affectionate, loyal, Sedate, Quiet Origin: Iran (Persia) Life span: 14 - 15 years Weight: 4 - 6 kg (9 - 14 lb) Grooming level: 5 Energy level...
# ====================================================================================================
# QUESTION: какая кошка умеет чинить ноутбук?
# STRATEGY: full_hybrid_retrieval
# DETECTED BREED: None
# --------------------------------------------------------------------------------
# rank: 1
# score: 0.1768
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.3214
# breed: Bambino
# breed_id: bamb
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bambino_cat
# reference_image_id: 5AdhMjeEu
# text: Breed name: Bambino Description: The Bambino is a breed of cat that was created as a cross between the Sphynx and the Munchkin breeds. The Bambino cat has short legs, large upright ears, and is usually hairless. They love to be handled and cuddled up on the laps of their family members. Temperament: Affectionate, Lively, Friendly, Intelligent Origin: United States Life span: 12 - 14 years Weight: 2 - 4 kg (4 - 9 lb) Grooming level: 1 Energy level...
# --------------------------------------------------------------------------------
# rank: 2
# score: 0.1678
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.3051
# breed: York Chocolate
# breed_id: ycho
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/York_Chocolate
# reference_image_id: 0SxW2SQ_S
# text: Breed name: York Chocolate Description: York Chocolate cats are known to be true lap cats with a sweet temperament. They love to be cuddled and petted. Their curious nature makes them follow you all the time and participate in almost everything you do, even if it's related to water: unlike many other cats, York Chocolates love it. Temperament: Playful, Social, Intelligent, Curious, Friendly Origin: United States Life span: 13 - 15 years Weight: 5...
# --------------------------------------------------------------------------------
# rank: 3
# score: 0.1661
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.3019
# breed: Norwegian Forest Cat
# breed_id: norw
# origin: Norway
# wikipedia_url: https://en.wikipedia.org/wiki/Norwegian_Forest_Cat
# reference_image_id: 06dgGmEOV
# text: Breed name: Norwegian Forest Cat Description: The Norwegian Forest Cat is a sweet, loving cat. She appreciates praise and loves to interact with her parent. She makes a loving companion and bonds with her parents once she accepts them for her own. She is still a hunter at heart. She loves to chase toys as if they are real. She is territorial and patrols several times each day to make certain that all is fine. Temperament: Sweet, Active, Intellige...
# --------------------------------------------------------------------------------
# rank: 4
# score: 0.1516
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.2757
# breed: Abyssinian
# breed_id: abys
# origin: Egypt
# wikipedia_url: https://en.wikipedia.org/wiki/Abyssinian_(cat)
# reference_image_id: 0XYvRd7oD
# text: Breed name: Abyssinian Description: The Abyssinian is easy to care for, and a joy to have in your home. They’re affectionate cats and love both people and other animals. Temperament: Active, Energetic, Independent, Intelligent, Gentle Origin: Egypt Life span: 14 - 15 years Weight: 3 - 5 kg (7  -  10 lb) Grooming level: 1 Energy level: 5 Health issues score: 2 Child friendly score: 3 Dog friendly score: 4 Stranger friendly score: 5 Intelligence sc...
# --------------------------------------------------------------------------------
# rank: 5
# score: 0.1507
# score_type: hybrid_structured_semantic
# structured_score: 0.0
# semantic_score: 0.274
# breed: Cheetoh
# breed_id: chee
# origin: United States
# wikipedia_url: https://en.wikipedia.org/wiki/Bengal_cat#Cheetoh
# reference_image_id: IFXsxmXLm
# text: Breed name: Cheetoh Description: The Cheetoh has a super affectionate nature and real love for their human companions; they are intelligent with the ability to learn quickly. You can expect that a Cheetoh will be a fun-loving kitty who enjoys playing, running, and jumping through every room in your house. Temperament: Affectionate, Gentle, Intelligent, Social Origin: United States Life span: 12 - 14 years Weight: 4 - 7 kg (8 - 15 lb) Grooming lev...

# %%
def build_full_rag_prompt(question: str, retrieved_result: Dict[str, Any]) -> str:
    context_blocks = []

    for item in retrieved_result.get("results", []):
        chunk = item["chunk"]
        metadata = chunk.get("metadata", {}) or {}

        block = f"""
[Context chunk]
Rank: {item.get("rank")}
Retrieval strategy: {retrieved_result.get("strategy")}
Final score: {item.get("score")}
Score type: {item.get("score_type")}
Structured score: {item.get("structured_score")}
Semantic score: {item.get("semantic_score")}
Breed: {chunk.get("breed_name")}
Breed ID: {chunk.get("breed_id")}
Origin: {metadata.get("origin")}
Wikipedia URL: {metadata.get("wikipedia_url")}
Reference image ID: {metadata.get("reference_image_id")}
Image URL: {metadata.get("image_url")}

Text:
{chunk.get("text")}
""".strip()

        context_blocks.append(block)

    if context_blocks:
        context_text = "\n\n---\n\n".join(context_blocks)
    else:
        context_text = "No relevant CatAPI context was retrieved."

    prompt = f"""
SYSTEM INSTRUCTION:
{SYSTEM_INSTRUCTION}

RETRIEVED CONTEXT:
{context_text}

USER QUESTION:
{question}

ANSWER:
""".strip()

    return prompt

# %%
question = "Какая кошка большая, спокойная и ласковая?"

retrieved = full_retrieve(question, top_k=3)
prompt = build_full_rag_prompt(question, retrieved)

print(prompt)
# Out:
# SYSTEM INSTRUCTION:
# Ты — дружелюбный ассистент-консультант по породам кошек.
#
# Отвечай на русском языке.
# Используй только факты из retrieved context.
# Если информации мало, честно скажи, что данных недостаточно.
# Не давай категоричных медицинских советов.
# Если вопрос касается здоровья, мягко посоветуй обратиться к ветеринару.
#
# RETRIEVED CONTEXT:
# [Context chunk]
# Rank: 1
# Retrieval strategy: full_hybrid_retrieval
# Final score: 0.45
# Score type: hybrid_structured_semantic
# Structured score: 1.0
# Semantic score: 0.0
# Breed: British Shorthair
# Breed ID: bsho
# Origin: United Kingdom
# Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
# Reference image ID: s4wQfYoEk
# Image URL: None
#
# Text:
# Breed name: British Shorthair
# Description: The British Shorthair is a very pleasant cat to have as a companion, ans is easy going and placid. The British is a fiercely loyal, loving cat and will attach herself to every one of her family members. While loving to play, she doesn't need hourly attention. If she is in the mood to play, she will find someone and bring a toy to that person. The British also plays well by herself, and thus is a good companion for single people.
# Temperament: Affectionate, Easy Going, Gentle, Loyal, Patient, calm
# Origin: United Kingdom
# Life span: 12 - 17 years
# Weight: 5 - 9 kg (12 - 20 lb)
# Grooming level: 2
# Energy level: 2
# Health issues score: 2
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 2
# Intelligence score: 3
# Hairless: no
# Shedding level: 4
# Social needs score: 3
# Vocalisation score: 1
# Hypoallergenic: 0
# Wikipedia URL: https://en.wikipedia.org/wiki/British_Shorthair
#
# ---
#
# [Context chunk]
# Rank: 2
# Retrieval strategy: full_hybrid_retrieval
# Final score: 0.315
# Score type: hybrid_structured_semantic
# Structured score: 0.7
# Semantic score: 0.0
# Breed: Ragamuffin
# Breed ID: raga
# Origin: United States
# Wikipedia URL: https://en.wikipedia.org/wiki/Ragamuffin_cat
# Reference image ID: SMuZx-bFM
# Image URL: None
#
# Text:
# Breed name: Ragamuffin
# Description: The Ragamuffin is calm, even tempered and gets along well with all family members. Changes in routine generally do not upset her. She is an ideal companion for those in apartments, and with children due to her patient nature.
# Temperament: Affectionate, Friendly, Gentle, Calm
# Origin: United States
# Life span: 12 - 16 years
# Weight: 4 - 9 kg (8 - 20 lb)
# Grooming level: 3
# Energy level: 3
# Health issues score: 3
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 5
# Intelligence score: 5
# Hairless: no
# Shedding level: 3
# Social needs score: 3
# Vocalisation score: 1
# Hypoallergenic: 0
# Wikipedia URL: https://en.wikipedia.org/wiki/Ragamuffin_cat
#
# ---
#
# [Context chunk]
# Rank: 3
# Retrieval strategy: full_hybrid_retrieval
# Final score: 0.315
# Score type: hybrid_structured_semantic
# Structured score: 0.7
# Semantic score: 0.0
# Breed: Ragdoll
# Breed ID: ragd
# Origin: United States
# Wikipedia URL: https://en.wikipedia.org/wiki/Ragdoll
# Reference image ID: oGefY4YoG
# Image URL: None
#
# Text:
# Breed name: Ragdoll
# Description: Ragdolls love their people, greeting them at the door, following them around the house, and leaping into a lap or snuggling in bed whenever given the chance. They are the epitome of a lap cat, enjoy being carried and collapsing into the arms of anyone who holds them.
# Temperament: Affectionate, Friendly, Gentle, Quiet, Easygoing
# Origin: United States
# Life span: 12 - 17 years
# Weight: 5 - 9 kg (12 - 20 lb)
# Grooming level: 2
# Energy level: 3
# Health issues score: 3
# Child friendly score: 4
# Dog friendly score: 5
# Stranger friendly score: 3
# Intelligence score: 3
# Hairless: no
# Shedding level: 3
# Social needs score: 5
# Vocalisation score: 1
# Hypoallergenic: 0
# Wikipedia URL: https://en.wikipedia.org/wiki/Ragdoll
#
# USER QUESTION:
# Какая кошка большая, спокойная и ласковая?
#
# ANSWER:

# %% [markdown]
# ## Full RAG components
#
# Теперь в notebook есть все ключевые компоненты RAG:
#
# 1. Data source:
#    `catapi_breed_documents.jsonl`, `catapi_chunks.jsonl`
#
# 2. Chunks:
#    один профиль породы = один chunk
#
# 3. Embedding model:
#    `sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2`
#
# 4. Vector index:
#    NumPy matrix `chunk_embeddings`
#
# 5. Vector store:
#    сохранённые файлы:
#    - `catapi_vector_index/catapi_chunk_embeddings.npy`
#    - `catapi_vector_index/catapi_chunk_ids.json`
#
# 6. Retriever:
#    `semantic_retrieve_v2`
#
# 7. Hybrid retriever:
#    `full_retrieve`
#
# 8. Prompt builder:
#    `build_full_rag_prompt`
#
# 9. Generator:
#    LLM provider или mock answer
#
# Вывод:
#
# Для русскоязычного ассистента по породам лучше использовать не чистый vector search, а гибридную схему:
#
# `breed alias detection → structured CatAPI retrieval → semantic vector retrieval → LLM answer`
